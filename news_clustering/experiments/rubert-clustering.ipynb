# %%
import torch
import pandas as pd
from torch import nn
from torch.nn import functional as F
from transformers import BertTokenizer, BertModel
import logging
import deeppavlov
logging.basicConfig(level=logging.INFO)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.

# %%
tokenizer = BertTokenizer.from_pretrained('./rubert_cased_L-12_H-768_A-12_pt')
print(tokenizer)
# Out:
# INFO:transformers.tokenization_utils:Model name './rubert_cased_L-12_H-768_A-12_pt' not found in model shortcut name list (bert-base-uncased, bert-large-uncased, bert-base-cased, bert-large-cased, bert-base-multilingual-uncased, bert-base-multilingual-cased, bert-base-chinese, bert-base-german-cased, bert-large-uncased-whole-word-masking, bert-large-cased-whole-word-masking, bert-large-uncased-whole-word-masking-finetuned-squad, bert-large-cased-whole-word-masking-finetuned-squad, bert-base-cased-finetuned-mrpc, bert-base-german-dbmdz-cased, bert-base-german-dbmdz-uncased). Assuming './rubert_cased_L-12_H-768_A-12_pt' is a path or url to a directory containing tokenizer files.
# INFO:transformers.tokenization_utils:Didn't find file ./rubert_cased_L-12_H-768_A-12_pt/added_tokens.json. We won't load it.
# INFO:transformers.tokenization_utils:Didn't find file ./rubert_cased_L-12_H-768_A-12_pt/special_tokens_map.json. We won't load it.
# INFO:transformers.tokenization_utils:Didn't find file ./rubert_cased_L-12_H-768_A-12_pt/tokenizer_config.json. We won't load it.
# INFO:transformers.tokenization_utils:loading file ./rubert_cased_L-12_H-768_A-12_pt/vocab.txt
# INFO:transformers.tokenization_utils:loading file None
# INFO:transformers.tokenization_utils:loading file None
# INFO:transformers.tokenization_utils:loading file None
# <transformers.tokenization_bert.BertTokenizer object at 0x7f119abd4950>

# %%
embedder = BertModel.from_pretrained('./rubert_cased_L-12_H-768_A-12_pt')
# Out:
# INFO:transformers.configuration_utils:loading configuration file ./rubert_cased_L-12_H-768_A-12_pt/config.json
# INFO:transformers.configuration_utils:Model config {
#   "attention_probs_dropout_prob": 0.1,
#   "directionality": "bidi",
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "num_labels": 2,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "output_past": true,
#   "pooler_fc_size": 768,
#   "pooler_num_attention_heads": 12,
#   "pooler_num_fc_layers": 3,
#   "pooler_size_per_head": 128,
#   "pooler_type": "first_token_transform",
#   "pruned_heads": {},
#   "torchscript": false,
#   "type_vocab_size": 2,
#   "use_bfloat16": false,
#   "vocab_size": 119547
# }
#
# INFO:transformers.modeling_utils:loading weights file ./rubert_cased_L-12_H-768_A-12_pt/pytorch_model.bin

# %%
class TripletNet(nn.Module):
    def __init__(self, embedding_net):
        super().__init__()
        self.embedding_net = embedding_net

    def forward(self, x1, x2, x3):
        output1 = self.embedding_net(x1)
        output2 = self.embedding_net(x2)
        output3 = self.embedding_net(x3)
        return output1, output2, output3

    def get_embedding(self, x):
        return self.embedding_net(x)

# %%
class TripletLoss(nn.Module):
    """
    Triplet loss
    Takes embeddings of an anchor sample, a positive sample and a negative sample
    """

    def __init__(self, margin):
        super(TripletLoss, self).__init__()
        self.margin = margin

    def forward(self, anchor, positive, negative, size_average=True):
        distance_positive = (anchor - positive).pow(2).sum(1)  # .pow(.5)
        distance_negative = (anchor - negative).pow(2).sum(1)  # .pow(.5)
        losses = F.relu(distance_positive - distance_negative + self.margin)
        return losses.mean() if size_average else losses.sum()

# %%
model = TripletNet(embedder)

# %%
# model.cuda()

# %%
df = pd.read_csv('./datasets/lenta-ru-news.csv', nrows=500)

# %%
df.tail()
# Out:
#                                              url  \
# 495       https://lenta.ru/news/1999/09/27/dili/
# 496        https://lenta.ru/news/1999/09/27/ort/
# 497       https://lenta.ru/news/1999/09/27/nasa/
# 498     https://lenta.ru/news/1999/09/27/shoigu/
# 499  https://lenta.ru/news/1999/09/27/cherkessk/
#
#                                                  title  \
# 495      Индонезийские войска оставляют за собой руины
# 496                        ОРТ начало вещание в Европе
# 497              NASA: космос пора продавать частникам
# 498                   Путину жаль расставаться с Шойгу
# 499  Госдума России вмешалась в конфликт в Карачаев...
#
#                                                   text   topic tags  \
# 495  Выводимые из Восточного Тимора индонезийские в...     Мир  Все
# 496  27 сентября Общественное российское телевидени...  Россия  Все
# 497  Вслед за случившейся на прошлой неделе потерей...     Мир  Все
# 498  Сергей Шойгу рассматривает возможность ухода в...  Россия  Все
# 499  Государственная Дума России вместе с главой Ка...  Россия  Все
#
#            date
# 495  1999/09/27
# 496  1999/09/27
# 497  1999/09/27
# 498  1999/09/27
# 499  1999/09/27

# %%
ner_model = deeppavlov.build_model(deeppavlov.configs.ner.ner_ontonotes_bert_mult, download=True)
# Out:
# 2020-04-26 18:32:22.701 INFO in 'deeppavlov.download'['download'] at line 117: Skipped http://files.deeppavlov.ai/deeppavlov_data/bert/multi_cased_L-12_H-768_A-12.zip download because of matching hashes
# INFO:deeppavlov.download:Skipped http://files.deeppavlov.ai/deeppavlov_data/bert/multi_cased_L-12_H-768_A-12.zip download because of matching hashes
# 2020-04-26 18:32:25.577 INFO in 'deeppavlov.download'['download'] at line 117: Skipped http://files.deeppavlov.ai/deeppavlov_data/ner_ontonotes_bert_mult_v1.tar.gz download because of matching hashes
# INFO:deeppavlov.download:Skipped http://files.deeppavlov.ai/deeppavlov_data/ner_ontonotes_bert_mult_v1.tar.gz download because of matching hashes
# WARNING:tensorflow:From /home/vsmaxim8/anaconda3/lib/python3.7/site-packages/bert_dp/tokenization.py:125: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
# [nltk_data] Downloading package punkt to /home/vsmaxim8/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/vsmaxim8/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package perluniprops to
# [nltk_data]     /home/vsmaxim8/nltk_data...
# [nltk_data]   Package perluniprops is already up-to-date!
# [nltk_data] Downloading package nonbreaking_prefixes to
# [nltk_data]     /home/vsmaxim8/nltk_data...
# [nltk_data]   Package nonbreaking_prefixes is already up-to-date!
# WARNING:tensorflow:From /home/vsmaxim8/anaconda3/lib/python3.7/site-packages/bert_dp/tokenization.py:125: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# 2020-04-26 18:32:26.842 INFO in 'deeppavlov.core.data.simple_vocab'['simple_vocab'] at line 115: [loading vocabulary from /home/vsmaxim8/.deeppavlov/models/ner_ontonotes_bert_mult/tag.dict]
# INFO:deeppavlov.core.data.simple_vocab:[loading vocabulary from /home/vsmaxim8/.deeppavlov/models/ner_ontonotes_bert_mult/tag.dict]
# WARNING:tensorflow:From /home/vsmaxim8/anaconda3/lib/python3.7/site-packages/deeppavlov/core/models/tf_model.py:37: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
# WARNING:tensorflow:From /home/vsmaxim8/anaconda3/lib/python3.7/site-packages/deeppavlov/core/models/tf_model.py:37: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
# WARNING:tensorflow:From /home/vsmaxim8/anaconda3/lib/python3.7/site-packages/deeppavlov/core/models/tf_model.py:222: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# WARNING:tensorflow:From /home/vsmaxim8/anaconda3/lib/python3.7/site-packages/deeppavlov/core/models/tf_model.py:222: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# WARNING:tensorflow:From /home/vsmaxim8/anaconda3/lib/python3.7/site-packages/deeppavlov/core/models/tf_model.py:222: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# WARNING:tensorflow:From /home/vsmaxim8/anaconda3/lib/python3.7/site-packages/deeppavlov/core/models/tf_model.py:222: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# WARNING:tensorflow:From /home/vsmaxim8/anaconda3/lib/python3.7/site-packages/deeppavlov/core/models/tf_model.py:193: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
# WARNING:tensorflow:From /home/vsmaxim8/anaconda3/lib/python3.7/site-packages/deeppavlov/core/models/tf_model.py:193: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
# WARNING:tensorflow:From /home/vsmaxim8/anaconda3/lib/python3.7/site-packages/deeppavlov/models/bert/bert_sequence_tagger.py:236: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
# WARNING:tensorflow:From /home/vsmaxim8/anaconda3/lib/python3.7/site-packages/deeppavlov/models/bert/bert_sequence_tagger.py:236: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
# WARNING:tensorflow:From /home/vsmaxim8/anaconda3/lib/python3.7/site-packages/deeppavlov/models/bert/bert_sequence_tagger.py:314: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
# WARNING:tensorflow:From /home/vsmaxim8/anaconda3/lib/python3.7/site-packages/deeppavlov/models/bert/bert_sequence_tagger.py:314: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
# WARNING:tensorflow:From /home/vsmaxim8/anaconda3/lib/python3.7/site-packages/bert_dp/modeling.py:178: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
# WARNING:tensorflow:From /home/vsmaxim8/anaconda3/lib/python3.7/site-packages/bert_dp/modeling.py:178: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
# WARNING:tensorflow:From /home/vsmaxim8/anaconda3/lib/python3.7/site-packages/bert_dp/modeling.py:418: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
# WARNING:tensorflow:From /home/vsmaxim8/anaconda3/lib/python3.7/site-packages/bert_dp/modeling.py:418: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
# WARNING:tensorflow:From /home/vsmaxim8/anaconda3/lib/python3.7/site-packages/bert_dp/modeling.py:499: The name tf.assert_less_equal is deprecated. Please use tf.compat.v1.assert_less_equal instead.
# WARNING:tensorflow:From /home/vsmaxim8/anaconda3/lib/python3.7/site-packages/bert_dp/modeling.py:499: The name tf.assert_less_equal is deprecated. Please use tf.compat.v1.assert_less_equal instead.
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
# WARNING:tensorflow:From /home/vsmaxim8/anaconda3/lib/python3.7/site-packages/bert_dp/modeling.py:366: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /home/vsmaxim8/anaconda3/lib/python3.7/site-packages/bert_dp/modeling.py:366: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /home/vsmaxim8/anaconda3/lib/python3.7/site-packages/bert_dp/modeling.py:680: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From /home/vsmaxim8/anaconda3/lib/python3.7/site-packages/bert_dp/modeling.py:680: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From /home/vsmaxim8/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/layers/core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /home/vsmaxim8/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/layers/core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /home/vsmaxim8/anaconda3/lib/python3.7/site-packages/bert_dp/modeling.py:283: The name tf.erf is deprecated. Please use tf.math.erf instead.
# WARNING:tensorflow:From /home/vsmaxim8/anaconda3/lib/python3.7/site-packages/bert_dp/modeling.py:283: The name tf.erf is deprecated. Please use tf.math.erf instead.
# WARNING:tensorflow:Variable *= will be deprecated. Use `var.assign(var * other)` if you want assignment to the variable value or `x = x * y` if you want a new python Tensor object.
# WARNING:tensorflow:Variable *= will be deprecated. Use `var.assign(var * other)` if you want assignment to the variable value or `x = x * y` if you want a new python Tensor object.
# WARNING:tensorflow:From /home/vsmaxim8/anaconda3/lib/python3.7/site-packages/deeppavlov/models/bert/bert_sequence_tagger.py:75: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/vsmaxim8/anaconda3/lib/python3.7/site-packages/deeppavlov/models/bert/bert_sequence_tagger.py:75: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/vsmaxim8/anaconda3/lib/python3.7/site-packages/tensorflow_core/contrib/crf/python/ops/crf.py:213: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /home/vsmaxim8/anaconda3/lib/python3.7/site-packages/tensorflow_core/contrib/crf/python/ops/crf.py:213: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /home/vsmaxim8/anaconda3/lib/python3.7/site-packages/deeppavlov/core/models/tf_model.py:234: The name tf.train.AdadeltaOptimizer is deprecated. Please use tf.compat.v1.train.AdadeltaOptimizer instead.
# WARNING:tensorflow:From /home/vsmaxim8/anaconda3/lib/python3.7/site-packages/deeppavlov/core/models/tf_model.py:234: The name tf.train.AdadeltaOptimizer is deprecated. Please use tf.compat.v1.train.AdadeltaOptimizer instead.
# WARNING:tensorflow:From /home/vsmaxim8/anaconda3/lib/python3.7/site-packages/deeppavlov/core/models/tf_model.py:131: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
# WARNING:tensorflow:From /home/vsmaxim8/anaconda3/lib/python3.7/site-packages/deeppavlov/core/models/tf_model.py:131: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
# WARNING:tensorflow:From /home/vsmaxim8/anaconda3/lib/python3.7/site-packages/deeppavlov/core/models/tf_model.py:131: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
# WARNING:tensorflow:From /home/vsmaxim8/anaconda3/lib/python3.7/site-packages/deeppavlov/core/models/tf_model.py:131: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
# WARNING:tensorflow:From /home/vsmaxim8/anaconda3/lib/python3.7/site-packages/deeppavlov/core/models/tf_model.py:94: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# WARNING:tensorflow:From /home/vsmaxim8/anaconda3/lib/python3.7/site-packages/deeppavlov/core/models/tf_model.py:94: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# WARNING:tensorflow:From /home/vsmaxim8/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/training/moving_averages.py:433: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# WARNING:tensorflow:From /home/vsmaxim8/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/training/moving_averages.py:433: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# WARNING:tensorflow:From /home/vsmaxim8/anaconda3/lib/python3.7/site-packages/deeppavlov/models/bert/bert_sequence_tagger.py:671: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
# WARNING:tensorflow:From /home/vsmaxim8/anaconda3/lib/python3.7/site-packages/deeppavlov/models/bert/bert_sequence_tagger.py:671: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
# WARNING:tensorflow:From /home/vsmaxim8/anaconda3/lib/python3.7/site-packages/deeppavlov/models/bert/bert_sequence_tagger.py:244: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
# WARNING:tensorflow:From /home/vsmaxim8/anaconda3/lib/python3.7/site-packages/deeppavlov/models/bert/bert_sequence_tagger.py:244: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
# WARNING:tensorflow:From /home/vsmaxim8/anaconda3/lib/python3.7/site-packages/deeppavlov/models/bert/bert_sequence_tagger.py:249: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# WARNING:tensorflow:From /home/vsmaxim8/anaconda3/lib/python3.7/site-packages/deeppavlov/models/bert/bert_sequence_tagger.py:249: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# 2020-04-26 18:32:54.652 INFO in 'deeppavlov.core.models.tf_model'['tf_model'] at line 51: [loading model from /home/vsmaxim8/.deeppavlov/models/ner_ontonotes_bert_mult/model]
# INFO:deeppavlov.core.models.tf_model:[loading model from /home/vsmaxim8/.deeppavlov/models/ner_ontonotes_bert_mult/model]
# WARNING:tensorflow:From /home/vsmaxim8/anaconda3/lib/python3.7/site-packages/deeppavlov/core/models/tf_model.py:54: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
# WARNING:tensorflow:From /home/vsmaxim8/anaconda3/lib/python3.7/site-packages/deeppavlov/core/models/tf_model.py:54: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
# INFO:tensorflow:Restoring parameters from /home/vsmaxim8/.deeppavlov/models/ner_ontonotes_bert_mult/model
# INFO:tensorflow:Restoring parameters from /home/vsmaxim8/.deeppavlov/models/ner_ontonotes_bert_mult/model

# %%
# preprocessing dataset
df[['title', 'text']] = df[['title', 'text']].apply(lambda i: i.replace('\xa0', ' '))
df['date'] = pd.to_datetime(df['date'], infer_datetime_format=True)

# %%
# getting named entities to make triplets
ner_titles = ner_model(df['title'])

# %%
ner_titles
# Out:
# [[['1914',
#    '.',
#    'Русские',
#    'войска',
#    'вступили',
#    'в',
#    '\xa0',
#    'пределы',
#    'Венгрии'],
#   ['1914',
#    '.',
#    'Празднование',
#    'столетия',
#    'М',
#    '.',
#    'Ю',
#    '.',
#    'Лермонтова',
#    'отложено'],
#   ['1914', '.', 'Das', 'ist', 'Nesteroff', '!'],
#   ['1914', '.', 'Бульдог', '-', 'гонец', 'под', 'Льежем'],
#   ['1914', '.', 'Под', 'Люблином', 'пойман', 'швабский', 'зверь'],
#   ['Космонавты', 'сомневаются', 'в', '\xa0', 'надежности', '"', 'Мира', '"'],
#   ['Взрыв',
#    'в',
#    '\xa0',
#    'центре',
#    'Москвы',
#    ':',
#    'пострадало',
#    '30',
#    '\xa0',
#    'человек'],
#   ['Япония',
#    'кредитует',
#    'Россию',
#    'на',
#    '\xa0',
#    'полтора',
#    'миллиарда',
#    'долларов'],
#   ['Британцы', 'отмечают', 'двухлетие', 'смерти', 'Дианы'],
#   ['Отмытые',
#    'через',
#    'Bank',
#    'of',
#    '\xa0',
#    'NY',
#    'деньги',
#    'не',
#    '\xa0',
#    'имели',
#    'отношения',
#    'к',
#    '\xa0',
#    'МВФ'],
#   ['C',
#    '1',
#    '\xa0',
#    'сентября',
#    'вводится',
#    'новая',
#    'форма',
#    'таможенной',
#    'декларации'],
#   ['Создан',
#    'департамент',
#    'ФСБ',
#    'по',
#    '\xa0',
#    'борьбе',
#    'с',
#    '\xa0',
#    'терроризмом'],
#   ['Южно', '-', 'Сахалинск', 'объявлен', 'очагом', 'холеры'],
#   ['Леворадикалы', 'создают', 'предвыборный', 'блок'],
#   ['Еще',
#    'одно',
#    'землетрясение',
#    'в',
#    '\xa0',
#    'Турции',
#    ':',
#    'один',
#    'человек',
#    'погиб',
#    ',',
#    'около',
#    '70',
#    '\xa0',
#    'ранены'],
#   ['В', 'горах', 'Дагестана', 'идут', 'активные', 'боевые', 'действия'],
#   ['Карачаево',
#    '-',
#    'Черкесия',
#    'раскололась',
#    'по',
#    '\xa0',
#    'национальному',
#    'признаку'],
#   ['Коржаков',
#    'готов',
#    'рассказать',
#    'Генпрокуратуре',
#    'про',
#    'финансовое',
#    'состояние',
#    'Ельцина'],
#   ['Российские',
#    'национал',
#    '-',
#    'большевики',
#    'убирают',
#    'территорию',
#    'Севастополя'],
#   ['Киргизия',
#    'ведет',
#    'бои',
#    'на',
#    '\xa0',
#    'границах',
#    'с',
#    '\xa0',
#    'Таджикистаном',
#    'и',
#    '\xa0',
#    'Узбекистаном'],
#   ['Литва', 'засудила', 'участников', 'переворота', '91', '\xa0', 'года'],
#   ['Референдум',
#    'по',
#    '\xa0',
#    'вопросу',
#    'о',
#    '\xa0',
#    'самоопределении',
#    'Восточного',
#    'Тимора',
#    'прошел',
#    'успешно'],
#   ['США',
#    'заплатили',
#    'Китаю',
#    '4',
#    ',',
#    '5',
#    '\xa0',
#    'миллиона',
#    'долларов',
#    'за',
#    '"',
#    'ошибочную',
#    'бомбардировку',
#    '"'],
#   ['Илюхин',
#    'и',
#    '\xa0',
#    'Исаков',
#    'отвернулись',
#    'от',
#    '\xa0',
#    'коммунистов'],
#   ['Паколли', ':', 'Дель', 'Понти', 'предлагала', 'мне', 'взятку'],
#   ['ФБР',
#    'готовится',
#    'к',
#    '\xa0',
#    'кибер',
#    '-',
#    'войне',
#    'и',
#    '\xa0',
#    'терактам',
#    'в',
#    '\xa0',
#    'канун',
#    '2000',
#    '\xa0',
#    'года'],
#   ['В',
#    '"',
#    'Bank',
#    'of',
#    '\xa0',
#    'New',
#    'York',
#    '"',
#    'подчищали',
#    'и',
#    '\xa0',
#    'уничтожали',
#    'документы'],
#   ['Федеральные',
#    'силы',
#    'в',
#    '\xa0',
#    'Дагестане',
#    'замкнули',
#    'кольцо',
#    'окружения'],
#   ['В', 'Киргизии', 'освобождены', 'трое', 'заложников'],
#   ['На', 'ММВБ', 'произошел', 'резкий', 'скачок', 'курса', 'доллара'],
#   ['Американские', 'миротворцы', 'скрывали', 'факт', 'массового', 'убийства'],
#   ['На', 'ММВБ', 'перестанут', 'торговать', 'немецкими', 'марками'],
#   ['Швейцарец', 'создал', 'подпольную', 'армию'],
#   ['В',
#    'центре',
#    'Буэнос',
#    '-',
#    'Айреса',
#    'разбился',
#    'самолет',
#    'со',
#    '\xa0',
#    '130',
#    '\xa0',
#    'пассажирами',
#    'на',
#    '\xa0',
#    'борту'],
#   ['США', 'хотят', 'сделать', 'паузу', 'в', '\xa0', 'кредитовании', 'России'],
#   ['Минюст',
#    'готовится',
#    'к',
#    '\xa0',
#    'борьбе',
#    'с',
#    '\xa0',
#    'политическими',
#    'экстремистами'],
#   ['Убит', 'абхазский', 'таможенник'],
#   ['Компания',
#    'Apple',
#    'выпустила',
#    '"',
#    'настольный',
#    'суперкомпьютер',
#    '"',
#    'Power',
#    'Mac',
#    'G4'],
#   ['Взрыв', 'на', '\xa0', 'Манежной', ':', 'новые', 'версии'],
#   ['"',
#    'Окружение',
#    'президента',
#    'не',
#    '\xa0',
#    'желает',
#    'объективного',
#    'расследования',
#    'скандала',
#    'вокруг',
#    'Bank',
#    'of',
#    '\xa0',
#    'New',
#    'York',
#    '"'],
#   ['Восточный',
#    'Тимор',
#    'после',
#    'референдума',
#    ':',
#    'анархия',
#    'и',
#    '\xa0',
#    'стрельба'],
#   ['Боевики', 'вытеснены', 'из', '\xa0', 'дагестанского', 'села', 'Карамахи'],
#   ['На',
#    'Павелецком',
#    'вокзале',
#    'обнаружен',
#    'предмет',
#    ',',
#    'напоминающий',
#    'взрывное',
#    'устройcтво'],
#   ['Курс', 'доллара', 'вырос', 'на', '\xa0', '65', '\xa0', 'копеек'],
#   ['Колокола',
#    ',',
#    'похищенные',
#    'из',
#    '\xa0',
#    'Свято',
#    '-',
#    'Троицкого',
#    'собора',
#    'в',
#    '\xa0',
#    'Сан',
#    '-',
#    'Франциско',
#    ',',
#    'возвращены'],
#   ['В', 'Чечне', 'отключили', 'ОРТ', 'и', '\xa0', 'РТР'],
#   ['CША',
#    'не',
#    '\xa0',
#    'будут',
#    'блокировать',
#    'выделение',
#    'России',
#    'кредита',
#    'МВФ'],
#   ['Авиакатастрофа', 'в', '\xa0', 'Танзании', ':', 'выживших', 'нет'],
#   ['КНДР',
#    'переносит',
#    'свою',
#    'морскую',
#    'границу',
#    'ближе',
#    'к',
#    '\xa0',
#    'берегам',
#    'Южной',
#    'Кореи'],
#   ['Минпечати', 'запретило', 'вещание', 'компании', '"', 'Петербург', '"'],
#   ['Курдская', 'рабочая', 'партия', 'складывает', 'оружие'],
#   ['В', 'Баткенском', 'районе', 'Киргизии', 'введен', 'комендантский', 'час'],
#   ['Ценные',
#    'приборы',
#    'с',
#    '"',
#    'Мира',
#    '"',
#    'отправят',
#    'на',
#    '\xa0',
#    'Землю'],
#   ['Возле', 'еврейской', 'школы', 'в', '\xa0', 'Москве', 'найдена', 'мина'],
#   ['ФБР',
#    'виновно',
#    'в',
#    '\xa0',
#    'гибели',
#    'более',
#    '80',
#    '\xa0',
#    'сектантов',
#    'в',
#    '\xa0',
#    'Уэйко'],
#   ['В', 'Москве', 'повышаются', 'цены', 'на', '\xa0', 'телефон'],
#   ['Ущерб',
#    'от',
#    '\xa0',
#    'взрыва',
#    'на',
#    '\xa0',
#    'Манежной',
#    'оценивается',
#    'в',
#    '\xa0',
#    '500',
#    '\xa0',
#    '000',
#    '\xa0',
#    'долларов'],
#   ['Глобальное', 'таяние', 'льдов', 'высвободит', 'древние', 'вирусы'],
#   ['В',
#    'Гонконге',
#    'разгромлен',
#    'синдикат',
#    'по',
#    '\xa0',
#    'производству',
#    'поддельных',
#    'компакт',
#    '-',
#    'дисков'],
#   ['В',
#    'Алтае',
#    'больше',
#    'половины',
#    'школ',
#    'закрыты',
#    'на',
#    '\xa0',
#    'забастовку'],
#   ['Минпечати', 'запретило', 'вещание', 'компании', '"', 'Петербург', '"'],
#   ['Ельцину', 'рассказали', 'про', 'Bank', 'of', '\xa0', 'New', 'York'],
#   ['Цены',
#    'на',
#    '\xa0',
#    'продукты',
#    'первой',
#    'необходимости',
#    'вырастут',
#    'вдвое'],
#   ['Спецпредставитель',
#    'президента',
#    'РФ',
#    '\xa0',
#    'Михаил',
#    'Задорнов',
#    'уходит',
#    'со',
#    '\xa0',
#    'своего',
#    'поста'],
#   ['Владимир', 'Путин', 'встретился', 'с', '\xa0', 'Эдуардом', 'Росселем'],
#   ['В',
#    'Южно',
#    '-',
#    'Сахалинске',
#    'выявлено',
#    '8',
#    '\xa0',
#    'больных',
#    'холерой'],
#   ['В', 'Восточном', 'Тиморе', 'убивают', 'сотрудников', 'ООН'],
#   ['Брюссельский',
#    '"',
#    'Писающий',
#    'мальчик',
#    '"',
#    'будет',
#    'писать',
#    'пивом',
#    '!'],
#   ['НАТО', 'выдвигается', 'на', '\xa0', 'Нобелевскую', 'премию', 'мира'],
#   ['Белый', 'дом', 'шлет', 'секретные', 'факсы', 'новозеландским', 'курицам'],
#   ['Запрет', 'на', '\xa0', 'вещание', 'ТРК', '"', 'Петербург', '"', 'снят'],
#   ['В', 'Москве', 'украли', 'генерального', 'директора'],
#   ['Бывший',
#    'директор',
#    'ОРТ',
#    'назначен',
#    'первым',
#    'замом',
#    'главы',
#    'администрации',
#    'президента'],
#   ['Экипажи',
#    'двух',
#    'российских',
#    'самолетов',
#    'стали',
#    'заложниками',
#    'ангольских',
#    'партизан'],
#   ['Деньги',
#    'Кремля',
#    'в',
#    '\xa0',
#    'Швейцарии',
#    ':',
#    'названы',
#    '24',
#    '\xa0',
#    'подозреваемых'],
#   ['В',
#    'Техасе',
#    'из',
#    '\xa0',
#    'мертвого',
#    'быка',
#    'сделали',
#    'живого',
#    'теленка'],
#   ['Полностью',
#    'вытеснить',
#    'боевиков',
#    'из',
#    '\xa0',
#    'Карамахи',
#    'так',
#    'и',
#    '\xa0',
#    'не',
#    'удалось'],
#   ['В', 'Севастополе', 'отключают', 'Черноморский', 'флот'],
#   ['Боевики',
#    'согласны',
#    'отпустить',
#    'заложников',
#    ',',
#    'захваченных',
#    'в',
#    '\xa0',
#    'Киргизии'],
#   ['Государство', 'хочет', 'контролировать', 'Интернет'],
#   ['Авария', 'на', '\xa0', 'Ярославском', 'вокзале'],
#   ['"',
#    'Mabetex',
#    '"',
#    'подает',
#    'в',
#    '\xa0',
#    'суд',
#    'на',
#    '"',
#    'Corrierre',
#    'della',
#    'Sera',
#    '"'],
#   ['В', 'Каму', 'вытекло', '100', '\xa0', 'тонн', 'мазута'],
#   ['Сторонники',
#    'Станислава',
#    'Дерева',
#    'не',
#    '\xa0',
#    'подчинились',
#    'Дереву'],
#   ['В',
#    'Омской',
#    'и',
#    '\xa0',
#    'Новгородской',
#    'областях',
#    'остались',
#    'прежние',
#    'губернаторы'],
#   ['Трое',
#    'террористов',
#    'погибли',
#    'во',
#    '\xa0',
#    'время',
#    'терактов',
#    'в',
#    '\xa0',
#    'Хайфе',
#    'и',
#    '\xa0',
#    'Тверии'],
#   ['В',
#    'бухту',
#    'Ласпи',
#    'с',
#    '\xa0',
#    'сухогруза',
#    '"',
#    'Кристина',
#    '"',
#    'вылилась',
#    'тонна',
#    'горючего'],
#   ['Правительство',
#    'Чечни',
#    'считает',
#    ',',
#    'что',
#    'Россия',
#    'начала',
#    'войну'],
#   ['В',
#    'драке',
#    'на',
#    '\xa0',
#    'Манежной',
#    'площади',
#    'пострадали',
#    'шесть',
#    'человек'],
#   ['Эпидемия', 'краснухи', 'в', '\xa0', 'Белгородской', 'области'],
#   ['Еще',
#    '11',
#    '\xa0',
#    'заложников',
#    'вернулись',
#    'из',
#    '\xa0',
#    'чеченского',
#    'плена'],
#   ['В',
#    'Непале',
#    'в',
#    '\xa0',
#    'авиакатастрофе',
#    'погибли',
#    '15',
#    '\xa0',
#    'человек'],
#   ['"', 'Держава', '"', 'выходит', 'из', '"', 'Отечества', '"'],
#   ['Пентагон',
#    'отключается',
#    'от',
#    '\xa0',
#    'Интернета',
#    ',',
#    'опасаясь',
#    'российских',
#    'хакеров'],
#   ['Спикер', 'Госдумы', 'Селезнев', 'хочет', 'отменить', 'президента'],
#   ['Чеченский',
#    'полевой',
#    'командир',
#    'Хаттаб',
#    'связан',
#    'с',
#    '\xa0',
#    'Бин',
#    '-',
#    'Ладеном'],
#   ['Бомбу', 'в', '"', 'Рамсторе', '"', 'не', '\xa0', 'нашли'],
#   ['Всеобщей', 'мобилизации', 'в', '\xa0', 'Дагестане', 'не', '\xa0', 'будет'],
#   ['200', '\xa0', 'сотрудников', 'ООН', 'покидают', 'Восточный', 'Тимор'],
#   ['В',
#    'Южно',
#    '-',
#    'Сахалинске',
#    'заболели',
#    'холерой',
#    '14',
#    '\xa0',
#    'человек'],
#   ['Новую', 'смертоносную', 'бактерию', 'назвали', '"', 'Визой', '"'],
#   ['Оползень',
#    'в',
#    '\xa0',
#    'Китае',
#    ':',
#    'более',
#    '200',
#    '\xa0',
#    'человек',
#    'погибли'],
#   ['Российские', 'миротворцы', 'застрелили', 'трех', 'косовских', 'сербов'],
#   ['На', 'президента', 'Египта', 'совершено', 'покушение'],
#   ['Программа', '"', 'Shuttle', '"', 'заморожена', 'до', '\xa0', 'ноября'],
#   ['Землетрясение', 'в', '\xa0', 'Греции'],
#   ['В',
#    'деле',
#    'о',
#    '\xa0',
#    'швейцарских',
#    'счетах',
#    'Ельцина',
#    'всплыл',
#    'первый',
#    'труп'],
#   ['"', 'Инкомбанк', '"', 'отстоял', 'свою', 'состоятельность'],
#   ['МВД',
#    'обвиняет',
#    'российские',
#    'банки',
#    'в',
#    '\xa0',
#    'помощи',
#    'чеченским',
#    'экстремистам'],
#   ['Переговоры',
#    'в',
#    '\xa0',
#    'Израиля',
#    'с',
#    '\xa0',
#    'Ливаном',
#    'фактически',
#    'провалились'],
#   ['Армия', 'освобождения', 'Косово', 'не', '\xa0', 'будет', 'расформирована'],
#   ['В', 'Черкесске', 'принят', '"', 'нулевой', 'вариант', '"'],
#   ['Индонезия',
#    'ввела',
#    'военное',
#    'положение',
#    'в',
#    '\xa0',
#    'Восточном',
#    'Тиморе'],
#   ['В', 'Индии', '300', '\xa0', 'человек', 'стали', 'жертвами', 'наводнений'],
#   ['Явлинский',
#    'связывает',
#    'кремлевский',
#    'скандал',
#    'с',
#    '\xa0',
#    'коллективным',
#    'прозрением',
#    'Запада'],
#   ['Еще', 'одно', 'назначение', 'Путина'],
#   ['В',
#    'Казахстане',
#    'от',
#    '\xa0',
#    'чего',
#    '-',
#    'то',
#    'похожего',
#    'на',
#    '\xa0',
#    'бубонную',
#    'чуму',
#    'умерла',
#    'девушка'],
#   ['В', 'космос', 'снова', 'запущен', '"', 'Протон', '"'],
#   ['Могилевич', 'выиграл', 'дело', 'в', '\xa0', 'суде'],
#   ['Блок',
#    '"',
#    'Отечество',
#    '\xa0',
#    '—',
#    'Вся',
#    'Россия',
#    '"',
#    'представил',
#    'в',
#    '\xa0',
#    'ЦИК',
#    'свои',
#    'списки'],
#   ['Березовский',
#    'отказался',
#    'баллотироваться',
#    'в',
#    '\xa0',
#    'Госдуму',
#    'от',
#    '\xa0',
#    'Еврейской',
#    'АО'],
#   ['По', 'Чечне', 'снова', 'нанесены', 'ракетно', '-', 'бомбовые', 'удары'],
#   ['В',
#    'Норильске',
#    'четыре',
#    'рабочих',
#    'погибли',
#    'в',
#    '\xa0',
#    'результате',
#    'взрыва'],
#   ['СОРМ', '-', '2', '\xa0', 'на', 'Украине', 'объявлен', 'вне', 'закона'],
#   ['Генштаб', 'РФ', '\xa0', 'вводит', 'военную', 'цензуру'],
#   ['В', 'Ачинске', 'начались', 'выступления', 'рабочих', 'против', 'Лебедя'],
#   ['Управделами',
#    'президента',
#    'Бородин',
#    'подает',
#    'в',
#    '\xa0',
#    'суд',
#    'на',
#    '"',
#    'Corriere',
#    'della',
#    'Sera',
#    '"'],
#   ['Судебный',
#    'процесс',
#    '"',
#    'Ford',
#    'против',
#    'Интернета',
#    '"',
#    'проиграл',
#    'Ford'],
#   ['В', 'Косово', 'гремят', 'взрывы'],
#   ['"',
#    'День',
#    'четырех',
#    'девяток',
#    '"',
#    '\xa0',
#    '—',
#    'репетиция',
#    '"',
#    'Ошибки',
#    '-',
#    '2000',
#    '"'],
#   ['Москвичи', 'не', '\xa0', 'хотят', 'видеть', 'Лужкова', 'президентом'],
#   ['Создана', 'первая', 'медиа', '-', 'империя', 'XXI', 'века'],
#   ['Россия', 'недовольна', 'процессами', 'в', '\xa0', 'Косово'],
#   ['Клинтон',
#    ',',
#    'Блэр',
#    ',',
#    'Мандела',
#    ',',
#    'Боно',
#    'и',
#    '\xa0',
#    'Дэвид',
#    'Боуи',
#    'встречаются',
#    'он',
#    '-',
#    'лайн'],
#   ['Нападение',
#    'на',
#    '\xa0',
#    'австралийское',
#    'посольство',
#    'в',
#    '\xa0',
#    'Джакарте'],
#   ['Министерство',
#    'налогов',
#    'и',
#    '\xa0',
#    'сборов',
#    'взялось',
#    'за',
#    '\xa0',
#    'АЗС'],
#   ['Московские',
#    'пожарные',
#    'предотвратили',
#    'катастрофу',
#    'на',
#    '\xa0',
#    'заводе',
#    '"',
#    'Нефтепродукт',
#    '"'],
#   ['Путин',
#    'прилетел',
#    'в',
#    '\xa0',
#    'Минск',
#    'и',
#    '\xa0',
#    'встретился',
#    'с',
#    '\xa0',
#    'Лукашенко'],
#   ['Умер', 'Лев', 'Разгон'],
#   ['Россия',
#    'получит',
#    'от',
#    '\xa0',
#    'Швейцарии',
#    'материалы',
#    'по',
#    '\xa0',
#    'делу',
#    '"',
#    'Аэрофлота',
#    '"'],
#   ['Выборы',
#    'мэра',
#    'и',
#    '\xa0',
#    'вице',
#    '-',
#    'мэра',
#    'Москвы',
#    'назначены',
#    'на',
#    '\xa0',
#    '19',
#    '\xa0',
#    'декабря'],
#   ['Японский', 'безработный', 'искромсал', 'восьмерых', 'человек'],
#   ['На', 'станции', '"', 'Мир', '"', 'выключен', 'главный', 'компьютер'],
#   ['Землетрясение',
#    'в',
#    '\xa0',
#    'Афинах',
#    ':',
#    '72',
#    '\xa0',
#    'человека',
#    'погибли',
#    ',',
#    '1500',
#    '\xa0',
#    'ранены'],
#   ['В', 'Азербайджане', 'открыто', 'крупное', 'месторождение', 'газа'],
#   ['Взрыв',
#    'в',
#    '\xa0',
#    'Москве',
#    ':',
#    '46',
#    '\xa0',
#    'погибших',
#    ',',
#    'трое',
#    'из',
#    '\xa0',
#    'них',
#    '\xa0',
#    '—',
#    'дети',
#    '.',
#    'Речь',
#    'идет',
#    'о',
#    '\xa0',
#    'теракте'],
#   ['Генпрокуратура',
#    'обыскала',
#    'дачу',
#    'и',
#    '\xa0',
#    'две',
#    'квартиры',
#    'Юрия',
#    'Скуратова'],
#   ['Березовский', 'в', '\xa0', 'больнице'],
#   ['ФБР', 'поможет', 'России', 'прикрыть', 'kavkaz', '.', 'org'],
#   ['В',
#    'Черкесске',
#    'взорваны',
#    'дома',
#    'активных',
#    'сторонников',
#    'генерала',
#    'Семенова'],
#   ['На',
#    'ОРТ',
#    'подали',
#    'в',
#    '\xa0',
#    'суд',
#    'за',
#    '\xa0',
#    'вольную',
#    'трактовку',
#    'интервью'],
#   ['"', 'Аэрофлот', '"', 'усиливает', 'борьбу', 'с', '\xa0', 'курильщиками'],
#   ['ЛДПР', 'не', '\xa0', 'дали', 'провести', 'пикет'],
#   ['Эпидемия',
#    'менингитной',
#    'лихорадки',
#    'в',
#    '\xa0',
#    'Волгограде',
#    'усиливается'],
#   ['Югославия',
#    'готова',
#    'силой',
#    'вернуть',
#    'Косово',
#    'в',
#    '\xa0',
#    'состав',
#    'Сербии'],
#   ['Депутаты', 'будут', 'ездить', 'в', '\xa0', 'электричках', 'без', 'льгот'],
#   ['В', 'Дагестане', 'сбит', 'российский', 'штурмовик', 'Су', '-', '25'],
#   ['Якушкин',
#    ':',
#    'военной',
#    'цензуры',
#    'в',
#    '\xa0',
#    'России',
#    'не',
#    '\xa0',
#    'будет'],
#   ['Чечня', 'обращается', 'за', '\xa0', 'помощью', 'в', '\xa0', 'ОБСЕ'],
#   ['Индонезия',
#    'не',
#    '\xa0',
#    'разрешила',
#    'ввести',
#    'войска',
#    'ООН',
#    'в',
#    '\xa0',
#    'Восточный',
#    'Тимор'],
#   ['В', 'России', 'может', 'быть', 'введено', 'военное', 'положение'],
#   ['Ельцин', 'отверг', 'обвинения', 'в', '\xa0', 'получении', 'взяток'],
#   ['Израиль', 'освобождает', 'палестинцев', 'из', '\xa0', 'заключения'],
#   ['Банк',
#    'Эстонии',
#    'печатает',
#    'дополнительные',
#    'деньги',
#    'из',
#    '-',
#    'за',
#    'боязни',
#    '"',
#    'Ошибки',
#    '-',
#    '2000',
#    '"'],
#   ['В', 'Курске', 'спекулируют', 'хлебом'],
#   ['Бензин', 'в', '\xa0', 'Москве', 'станет', 'еще', 'дороже'],
#   ['Дагестан',
#    ':',
#    'федеральные',
#    'силы',
#    'почти',
#    'захватили',
#    'село',
#    'Чабанмахи'],
#   ['13',
#    '\xa0',
#    'сентября',
#    'в',
#    '\xa0',
#    'России',
#    'объявлено',
#    'днем',
#    'траура'],
#   ['Найдено',
#    'судно',
#    ',',
#    'спасавшее',
#    'пассажиров',
#    'с',
#    '"',
#    'Титаника',
#    '"'],
#   ['Cкандал',
#    'с',
#    '"',
#    'отмывкой',
#    'денег',
#    '"',
#    'не',
#    '\xa0',
#    'отразится',
#    'на',
#    '\xa0',
#    'отношениях',
#    'США',
#    'и',
#    '\xa0',
#    'России',
#    ',',
#    'считает',
#    'Олбрайт'],
#   ['Очередной',
#    'транш',
#    'кредита',
#    'МВФ',
#    'будет',
#    'отложен',
#    'до',
#    '\xa0',
#    'октября'],
#   ['Генштаб',
#    'опровергает',
#    'сообщения',
#    'о',
#    '\xa0',
#    'бомбардировке',
#    'Чечни'],
#   ['Франция', 'собирается', 'запретить', 'саентологию'],
#   ['MTV', 'раздало', 'награды', 'за', '\xa0', '1999', '\xa0', 'год'],
#   ['При',
#    'обыске',
#    'у',
#    '\xa0',
#    'Скуратова',
#    'изъяли',
#    'видеокассеты',
#    ',',
#    'похожие',
#    'на',
#    '\xa0',
#    'семейные'],
#   ['В', 'Черкесске', 'ранен', 'активист', 'штаба', 'генерала', 'Семенова'],
#   ['С',
#    '1',
#    '\xa0',
#    'ноября',
#    'до',
#    '\xa0',
#    'аэропорта',
#    'Домодедово',
#    'можно',
#    'будет',
#    'доехать',
#    'на',
#    '\xa0',
#    'скоростной',
#    'электричке'],
#   ['В', 'Москве', 'восстановлен', 'Народный', 'контроль'],
#   ['Угроза', 'взрыва', 'торгового', 'комплекса', '"', 'Охотный', 'Ряд', '"'],
#   ['Премьер',
#    'РФ',
#    '\xa0',
#    'одобрил',
#    'план',
#    'мер',
#    'по',
#    '\xa0',
#    'предотвращению',
#    'новых',
#    'терактов'],
#   ['Новейшую', 'военную', 'технику', 'пытались', 'сбыть', 'Китаю'],
#   ['ЦРУ',
#    'назвало',
#    'главных',
#    'ракетных',
#    'врагов',
#    'США',
#    ':',
#    'Россия',
#    ',',
#    'Китай',
#    ',',
#    'Северная',
#    'Корея'],
#   ['ВГТРК', 'стоит', 'на', '\xa0', 'грани', 'банкротства'],
#   ['Спасательные', 'работы', 'в', '\xa0', 'Афинах', 'завершаются'],
#   ['В',
#    'офисе',
#    'Mabetex',
#    'нашли',
#    'документы',
#    'о',
#    '\xa0',
#    'счетах',
#    'Ельцина'],
#   ['На',
#    'Лубянке',
#    'обезврежен',
#    'пакет',
#    'картошки',
#    'с',
#    '\xa0',
#    'будильником'],
#   ['Из',
#    '-',
#    'за',
#    'опасности',
#    'терактов',
#    'Минатом',
#    'усиливает',
#    'охрану',
#    'ядерных',
#    'объектов'],
#   ['ММВБ', 'бьет', 'рекорд', 'по', '\xa0', 'объему', 'торгов', 'валютой'],
#   ['Таможня',
#    'снижает',
#    'пошлины',
#    'на',
#    '\xa0',
#    'ввоз',
#    'автомобилей',
#    'из',
#    '\xa0',
#    'Польши'],
#   ['На', 'Венецианском', 'кинофестивале', 'победили', 'китайцы'],
#   ['Чуть',
#    'не',
#    '\xa0',
#    'сгорел',
#    'центральный',
#    'вокзал',
#    'Нью',
#    '-',
#    'Йорка'],
#   ['В', 'Москве', 'найдены', 'новые', 'бомбы'],
#   ['Россия',
#    'после',
#    'взрывов',
#    ':',
#    'ужесточаются',
#    'меры',
#    'безопасности',
#    'и',
#    '\xa0',
#    'контроля'],
#   ['30',
#    '\xa0',
#    'вооруженных',
#    'чеченских',
#    'боевиков',
#    'вторглись',
#    'на',
#    '\xa0',
#    'Ставрополье'],
#   ['Newsweek',
#    ':',
#    'Россия',
#    'использует',
#    'хакеров',
#    'для',
#    'взлома',
#    'компьютеров',
#    'Пентагона'],
#   ['Теракт',
#    'в',
#    '\xa0',
#    'Москве',
#    ':',
#    '109',
#    '\xa0',
#    'погибших',
#    '.',
#    'Задержаны',
#    'подозреваемые'],
#   ['В', 'Турции', 'случилось', 'еще', 'одно', 'землетрясение'],
#   ['Россиянин',
#    'пытался',
#    'вывезти',
#    'из',
#    '\xa0',
#    'США',
#    'секретный',
#    'радар'],
#   ['Слияние', 'крупнейших', 'нефтяных', 'компаний'],
#   ['Corriere', 'della', 'Sera', 'публикует', 'письмо', 'Волошина'],
#   ['Ельцин',
#    ':',
#    '"',
#    'Террористы',
#    '\xa0',
#    '—',
#    'враги',
#    'без',
#    'совести',
#    ',',
#    'жалости',
#    'и',
#    '\xa0',
#    'чести',
#    '"'],
#   ['Путин',
#    'с',
#    '\xa0',
#    'Клинтоном',
#    'обсудили',
#    'терроризм',
#    'и',
#    '\xa0',
#    'утечку',
#    'денег'],
#   ['Крупнейшее', 'ограбление', 'банка', 'в', '\xa0', 'Эстонии'],
#   ['Израиль',
#    'и',
#    '\xa0',
#    'палестинцы',
#    'начинают',
#    'переговоры',
#    'длиною',
#    'в',
#    '\xa0',
#    'год'],
#   ['Села',
#    'Карамахи',
#    'и',
#    '\xa0',
#    'Чабанмахи',
#    'очищены',
#    'от',
#    '\xa0',
#    'боевиков'],
#   ['Советская', 'разведка', 'знала', 'все', 'секреты', 'Запада'],
#   ['"',
#    'Дело',
#    'о',
#    '\xa0',
#    '15',
#    '\xa0',
#    'миллиардах',
#    '"',
#    ':',
#    'подозреваются',
#    '780',
#    '\xa0',
#    'российских',
#    'чиновников'],
#   ['Deutsche',
#    'Bank',
#    'и',
#    '\xa0',
#    'Dresdner',
#    'Bank',
#    'заявили',
#    'властям',
#    'о',
#    '\xa0',
#    'перекачке',
#    'миллиардных',
#    'сумм',
#    'из',
#    '\xa0',
#    'России'],
#   ['На',
#    'выборах',
#    'губернатора',
#    'Свердловской',
#    'области',
#    'победил',
#    'Эдуард',
#    'Россель'],
#   ['13',
#    '\xa0',
#    'сентября',
#    '\xa0',
#    '—',
#    'день',
#    'траура',
#    'по',
#    '\xa0',
#    'погибшим',
#    'от',
#    '\xa0',
#    'взрывов',
#    'в',
#    '\xa0',
#    'Москве',
#    'и',
#    '\xa0',
#    'Буйнакске'],
#   ['В', 'Швейцарии', 'заморожены', 'счета', 'Бориса', 'Березовского'],
#   ['На', 'химзаводе', 'в', '\xa0', 'Мытищах', 'произошел', 'сильный', 'пожар'],
#   ['В',
#    'Москве',
#    'планируется',
#    'ввести',
#    'должность',
#    '"',
#    'старшего',
#    'по',
#    '\xa0',
#    'подъезду',
#    '"'],
#   ['Владимир',
#    'Путин',
#    ':',
#    'терроризм',
#    'стал',
#    'национальной',
#    'проблемой',
#    'России'],
#   ['США', 'возвращают', 'своего', 'посла', 'в', '\xa0', 'Белоруссию'],
#   ['Ураган',
#    'Флойд',
#    'идет',
#    'на',
#    '\xa0',
#    'Флориду',
#    ':',
#    'миллион',
#    'человек',
#    'эвакуируется',
#    ',',
#    '"',
#    'шаттлы',
#    '"',
#    'остаются'],
#   ['Виктор',
#    'Калюжный',
#    'утвержден',
#    'главой',
#    'коллегии',
#    'госпредставителей',
#    'в',
#    '"',
#    'Транснефти',
#    '"'],
#   ['C',
#    '16',
#    '\xa0',
#    'сентября',
#    'измененятся',
#    'правила',
#    'таможенного',
#    'оформления',
#    'товаров'],
#   ['Раиса', 'Горбачева', 'переведена', 'в', '\xa0', 'реанимацию'],
#   ['В',
#    'МГУ',
#    'действует',
#    'усиленный',
#    'контрольно',
#    '-',
#    'пропускной',
#    'режим'],
#   ['Теракт', 'в', '\xa0', 'Москве', ':', '121', '\xa0', 'человек', 'погиб'],
#   ['В',
#    'Москве',
#    'на',
#    '\xa0',
#    'Борисовских',
#    'прудах',
#    'обезврежена',
#    'взрывчатка'],
#   ['Испанская', 'полиция', 'арестовала', 'трех', 'российских', 'хакеров'],
#   ['160',
#    '\xa0',
#    'российских',
#    'городов',
#    'задыхаются',
#    'от',
#    '\xa0',
#    'химических',
#    'выбросов'],
#   ['В',
#    'Лондоне',
#    'обсуждается',
#    'вопрос',
#    'реструктуризации',
#    'долгов',
#    'бывшего',
#    'СССР'],
#   ['Путин',
#    ':',
#    'чрезвычайное',
#    'положение',
#    'пока',
#    'не',
#    '\xa0',
#    'вводится'],
#   ['The',
#    'Times',
#    ':',
#    'КБ',
#    '\xa0',
#    'Сухого',
#    'связан',
#    'с',
#    '\xa0',
#    'русской',
#    'мафией'],
#   ['Китай',
#    'собирается',
#    'запретить',
#    'иностранные',
#    'инвестиции',
#    'в',
#    '\xa0',
#    'Интернет'],
#   ['Последние',
#    'события',
#    'в',
#    '\xa0',
#    'Москве',
#    'и',
#    '\xa0',
#    'в',
#    'Дагестане',
#    'изменили',
#    'расписание',
#    'работы',
#    'Госдумы'],
#   ['В', 'Греции', 'сожгли', 'три', 'машины', 'российских', 'дипломатов'],
#   ['Генпрокурор',
#    'Казахстана',
#    'не',
#    '\xa0',
#    'смог',
#    'вернуть',
#    'бывшего',
#    'премьера',
#    'Кажегельдина',
#    'домой'],
#   ['Новый',
#    'глава',
#    'Карачаево',
#    '-',
#    'Черкесии',
#    'вступил',
#    'в',
#    '\xa0',
#    'должность'],
#   ['МВД', 'рассчитывает', 'на', '\xa0', 'бдительность', 'горожан'],
#   ['Новый', 'подземный', 'толчок', 'в', '\xa0', 'Турции'],
#   ['Льготы',
#    'на',
#    '\xa0',
#    'ввоз',
#    'легковых',
#    'автомашин',
#    'будут',
#    'отменены'],
#   ['Российская',
#    'делегация',
#    'проведет',
#    'в',
#    '\xa0',
#    'США',
#    'переговоры',
#    'по',
#    '\xa0',
#    'проблеме',
#    '"',
#    'отмывания',
#    'денег',
#    '"'],
#   ['Военные',
#    'России',
#    'и',
#    '\xa0',
#    'США',
#    'создают',
#    'центр',
#    'по',
#    '\xa0',
#    'предотвращению',
#    '"',
#    'ракетной',
#    'ошибки',
#    '-',
#    '2000',
#    '"'],
#   ['Тысячи',
#    'жителей',
#    'домов',
#    'на',
#    '\xa0',
#    'улице',
#    'Красного',
#    'маяка',
#    'покинули',
#    'свои',
#    'дома'],
#   ['Жители',
#    'четырех',
#    'дагестанских',
#    'селений',
#    'перекрыли',
#    'автодорогу',
#    'и',
#    '\xa0',
#    'требовали',
#    'выдать',
#    'им',
#    '\xa0',
#    'оружие'],
#   ['Трагедия', 'на', '\xa0', 'Каширском', 'шоссе', ':', 'фоторепортаж'],
#   ['Представителям', 'Чечни', 'в', '\xa0', 'Москве', 'угрожают', 'погромами'],
#   ['Британский',
#    'путеводитель',
#    'по',
#    '"',
#    'Проблеме',
#    '2000',
#    '"',
#    ':',
#    'ехать',
#    'на',
#    '\xa0',
#    'Украину',
#    'не',
#    '\xa0',
#    'рекомендуется'],
#   ['Сообщение',
#    'о',
#    '\xa0',
#    'бомбе',
#    'в',
#    '\xa0',
#    'центре',
#    'Москвы',
#    'не',
#    '\xa0',
#    'подтвердилось'],
#   ['В',
#    'Чернобыле',
#    'впервые',
#    'после',
#    'аварии',
#    'на',
#    '\xa0',
#    'ЧАЭС',
#    'родился',
#    'ребенок'],
#   ['ОМОН',
#    'стягивает',
#    'силы',
#    'к',
#    '\xa0',
#    'центральному',
#    'офису',
#    '"',
#    'Транснефти',
#    '"'],
#   ['Пятеро',
#    'мусульманских',
#    'террористов',
#    'во',
#    '\xa0',
#    'Франции',
#    'получили',
#    'по',
#    '\xa0',
#    'десять',
#    'лет',
#    'тюрьмы'],
#   ['55',
#    '\xa0',
#    'пассажиров',
#    'пострадали',
#    'в',
#    '\xa0',
#    'результате',
#    'аварии',
#    'британского',
#    'авиалайнера'],
#   ['Ураган', 'Флойд', 'готов', 'обрушиться', 'на', '\xa0', 'побережье', 'США'],
#   ['По',
#    'подозрению',
#    'в',
#    '\xa0',
#    'причастности',
#    'к',
#    '\xa0',
#    'взрыву',
#    'задержаны',
#    '27',
#    '\xa0',
#    'человек'],
#   ['Слухи',
#    'о',
#    '\xa0',
#    'cкором',
#    'уходе',
#    'Ельцина',
#    'в',
#    '\xa0',
#    'отставку',
#    'cильно',
#    'преувеличены',
#    '?'],
#   ['В', 'российской', 'воинской', 'части', 'задержан', 'японский', 'шпион'],
#   ['На', 'Северном', 'Кавказе', 'ограблены', 'два', 'автобуса'],
#   ['Юрий',
#    'Скуратов',
#    'подает',
#    'в',
#    '\xa0',
#    'суд',
#    'на',
#    '\xa0',
#    'Генпрокуратуру'],
#   ['Открылась', '54', '-', 'я', 'сессия', 'Генеральной', 'Ассамблеи', 'ООН'],
#   ['В', 'Черкесске', 'взорвали', 'и', '\xa0', 'сожгли', 'три', 'кафе'],
#   ['За',
#    'минувшие',
#    'трое',
#    'суток',
#    'в',
#    '\xa0',
#    'Шри',
#    '-',
#    'Ланке',
#    'погибло',
#    'около',
#    '200',
#    '\xa0',
#    'человек'],
#   ['Первый',
#    'замминистра',
#    'иностранных',
#    'дел',
#    'Греции',
#    'погиб',
#    'в',
#    '\xa0',
#    'авиакатастрофе'],
#   ['Лужков',
#    'открыл',
#    'свой',
#    'сайт',
#    'и',
#    '\xa0',
#    'готовится',
#    'провести',
#    'интернет',
#    '-',
#    'конференцию',
#    'на',
#    '\xa0',
#    'MSNBC'],
#   ['Каждому',
#    'депутату',
#    'положено',
#    'по',
#    '\xa0',
#    '10',
#    '\xa0',
#    'минут',
#    'в',
#    '\xa0',
#    'эфире',
#    'ежемесячно'],
#   ['Банк', 'Barclays', 'закрывает', 'счета', 'российских', 'клиентов'],
#   ['Совет',
#    'безопасности',
#    'ООН',
#    'решил',
#    'ввести',
#    'войска',
#    'в',
#    '\xa0',
#    'Восточный',
#    'Тимор'],
#   ['МВД', 'создает', 'службу', 'по', '\xa0', 'борьбе', 'с', '\xa0', 'мафией'],
#   ['Была', 'ли', '\xa0', 'у', 'Лебедя', '"', 'черная', 'касса', '"', '?'],
#   ['Рушайло', 'и', '\xa0', 'Квашнин', 'вылетели', 'на', '\xa0', 'Кавказ'],
#   ['Госдепартамент',
#    'США',
#    'предложил',
#    'России',
#    'помощь',
#    'в',
#    '\xa0',
#    'расследовании',
#    'терактов'],
#   ['На', 'Севере', 'России', 'пропал', 'вертолет'],
#   ['В', 'Анапе', 'завершился', 'фестиваль', '"', 'Киношок', '"'],
#   ['Найдены',
#    'зенитные',
#    'комплексы',
#    ',',
#    'похищенные',
#    'из',
#    '\xa0',
#    'войсковой',
#    'части'],
#   ['ОМОН', 'занял', 'здание', 'компании', '"', 'Транснефть', '"'],
#   ['В',
#    'Волгодонске',
#    'взорван',
#    'жилой',
#    'дом',
#    ':',
#    '18',
#    '\xa0',
#    'погибших'],
#   ['Ураган', 'Флойд', 'крушит', 'Америку'],
#   ['Московская',
#    'милиция',
#    'ловит',
#    'иногородних',
#    ':',
#    'более',
#    '20',
#    '\xa0',
#    'тысяч',
#    'человек',
#    'уже',
#    'задержано'],
#   ['New',
#    'York',
#    'Times',
#    ':',
#    'Егор',
#    'Строев',
#    '\xa0',
#    '—',
#    'за',
#    '\xa0',
#    'отставку',
#    'Ельцина'],
#   ['Западные',
#    'банки',
#    'думают',
#    'о',
#    '\xa0',
#    'сокращении',
#    'своего',
#    'присутствия',
#    'в',
#    '\xa0',
#    'России'],
#   ['В',
#    'Чертанове',
#    'бомбу',
#    'не',
#    '\xa0',
#    'нашли',
#    ',',
#    'но',
#    '\xa0',
#    'поиски',
#    'продолжаются',
#    '.',
#    'Эвакуированы',
#    'жители',
#    'еще',
#    '4',
#    '-',
#    'х',
#    'домов'],
#   ['В',
#    'Сахалинской',
#    'области',
#    'выявлено',
#    '11',
#    '\xa0',
#    'больных',
#    'холерой'],
#   ['В',
#    'Дагестане',
#    'задержан',
#    'предполагаемый',
#    'организатор',
#    'взрыва',
#    'в',
#    '\xa0',
#    'Буйнакске'],
#   ['В', 'Москве', 'предотвращены', 'новые', 'теракты'],
#   ['После',
#    'взрывов',
#    ':',
#    'реакция',
#    'лидеров',
#    'и',
#    '\xa0',
#    'народа',
#    'России'],
#   ['Черкесия', 'провозглашена', 'автономией'],
#   ['У',
#    'США',
#    'нет',
#    'данных',
#    'о',
#    '\xa0',
#    'прохождении',
#    'средств',
#    'МВФ',
#    'через',
#    'Bank',
#    'of',
#    '\xa0',
#    'New',
#    'York'],
#   ['Тайфун', 'Йорк', 'обрушился', 'на', '\xa0', 'Гонконг'],
#   ['Глава',
#    'российской',
#    'прокуратуры',
#    'призывает',
#    'разобраться',
#    'с',
#    '\xa0',
#    'чеченцами',
#    'на',
#    '\xa0',
#    'их',
#    'территории'],
#   ['Касьянов', 'уговорил', 'лондонских', 'кредиторов'],
#   ['Обнаружен',
#    '"',
#    'Мерседес',
#    '"',
#    ',',
#    'доставивший',
#    'взрывчатку',
#    'в',
#    '\xa0',
#    'Москву'],
#   ['Милошевич', 'стал', '"', 'невыездным', '"'],
#   ['Состояние', 'Раисы', 'Горбачевой', 'критическое'],
#   ['Территория',
#    'Дагестана',
#    'полностью',
#    'очищена',
#    'от',
#    '\xa0',
#    'боевиков'],
#   ['Индонезия',
#    'разорвала',
#    'договор',
#    'о',
#    '\xa0',
#    'безопасности',
#    'с',
#    '\xa0',
#    'Австралией'],
#   ['Путин', 'обвинил', 'Татарстан', 'в', '\xa0', 'разрушении', 'армии'],
#   ['Биньямина',
#    'Нетаниягу',
#    'подозревают',
#    'в',
#    '\xa0',
#    'финансовых',
#    'махинациях'],
#   ['В',
#    'индийском',
#    'штате',
#    'Джамму',
#    'и',
#    '\xa0',
#    'Кашмир',
#    'погибло',
#    '19',
#    '\xa0',
#    'человек'],
#   ['Установлены',
#    'единые',
#    'ставки',
#    'пошлин',
#    'на',
#    '\xa0',
#    'ввоз',
#    'в',
#    '\xa0',
#    'Россию',
#    'подержанных',
#    'автомашин'],
#   ['Террорист',
#    'расстрелял',
#    '8',
#    '\xa0',
#    'человек',
#    'в',
#    '\xa0',
#    'церкви',
#    'Техаса'],
#   ['В', 'XXI', 'веке', 'Америку', 'ждут', 'большие', 'проблемы'],
#   ['Ельцин',
#    'отправил',
#    'в',
#    '\xa0',
#    'отставку',
#    'министра',
#    'путей',
#    'сообщения'],
#   ['Березовский',
#    'подает',
#    'в',
#    '\xa0',
#    'суд',
#    'на',
#    '"',
#    'МК',
#    '"',
#    'и',
#    '\xa0',
#    'обвиняет',
#    'российские',
#    'спецслужбы',
#    'в',
#    '\xa0',
#    'бездействии'],
#   ['Взрыв',
#    'дома',
#    'в',
#    '\xa0',
#    'Петербурге',
#    'не',
#    '\xa0',
#    'имеет',
#    'отношения',
#    'к',
#    '\xa0',
#    'последним',
#    'терактам'],
#   ['Times', 'печатает', '"', 'Архивы', 'КГБ', '"'],
#   ['Президент',
#    'Чечни',
#    'Масхадов',
#    ':',
#    '"',
#    'Я',
#    'боюсь',
#    'афганского',
#    'сценария',
#    '"'],
#   ['МВД',
#    'назвало',
#    'имя',
#    'главного',
#    'подозреваемого',
#    'в',
#    '\xa0',
#    'терактах'],
#   ['В',
#    'Южной',
#    'Азии',
#    'обнаружен',
#    'новый',
#    'смертельно',
#    'опасный',
#    'вирус'],
#   ['США',
#    'откажется',
#    'помогать',
#    'России',
#    ',',
#    'если',
#    'она',
#    'не',
#    '\xa0',
#    'разберется',
#    'с',
#    '\xa0',
#    'коррупцией'],
#   ['Спецcлужбы',
#    'Турции',
#    'предотвратили',
#    'покушение',
#    'на',
#    '\xa0',
#    'министра',
#    'иностранных',
#    'дел',
#    'Италии'],
#   ['Ураган', 'Флойд', ':', 'погибло', '17', '\xa0', 'человек'],
#   ['Закон',
#    'о',
#    '\xa0',
#    'разрешении',
#    'сильного',
#    'шифрования',
#    'дает',
#    'ФБР',
#    'новый',
#    'способ',
#    'электронного',
#    'контроля'],
#   ['Более',
#    '20',
#    '\xa0',
#    'тысяч',
#    'чеченцев',
#    'бежали',
#    'от',
#    '\xa0',
#    'налетов',
#    'российской',
#    'авиации'],
#   ['Анатолия',
#    'Быкова',
#    'разыскивает',
#    'Интерпол',
#    'и',
#    '\xa0',
#    'поддерживает',
#    'ЛДПР'],
#   ['В', 'Москве', 'создан', 'неприкосновенный', 'запас', 'донорской', 'крови'],
#   ['"',
#    'Делом',
#    'о',
#    '$',
#    '15',
#    '\xa0',
#    'миллиардах',
#    '"',
#    'занимается',
#    'Интерпол'],
#   ['Двое', 'подозреваемых', 'в', '\xa0', 'московских', 'взрывах', 'задержаны'],
#   ['Деньги', 'МВФ', 'расходовались', 'правильно'],
#   ['Совет',
#    'Федерации',
#    'отказался',
#    'обсуждать',
#    'вопрос',
#    'об',
#    '\xa0',
#    'отставке',
#    'президента'],
#   ['Зарубежные', 'спецслужбы', 'помогут', 'России'],
#   ['Ельцин', 'не', '\xa0', 'обиделся', 'на', '\xa0', 'Строева'],
#   ['Минпечати',
#    'предупреждает',
#    'СМИ',
#    ',',
#    'подстрекающие',
#    'к',
#    '\xa0',
#    'погромам'],
#   ['В', 'Дагестане', 'воевали', 'люди', 'Масхадова'],
#   ['Названо', 'число', 'погибших', 'в', '\xa0', 'Дагестане'],
#   ['Жириновский', 'опять', 'подрался', 'в', '\xa0', 'Думе'],
#   ['Wall',
#    'Street',
#    'Journal',
#    ':',
#    'что',
#    'они',
#    'писали',
#    'на',
#    '\xa0',
#    'самом',
#    'деле'],
#   ['Акция', '"', 'Всё', 'в', '\xa0', 'наших', 'руках', '"'],
#   ['Скончалась', 'Раиса', 'Горбачева'],
#   ['1',
#    '\xa0',
#    '100',
#    '\xa0',
#    'туристов',
#    'вынужденно',
#    'дрейфуют',
#    'в',
#    '\xa0',
#    'Мексиканском',
#    'заливе'],
#   ['Российский',
#    'олигарх',
#    'не',
#    '\xa0',
#    'будет',
#    'отчитываться',
#    'перед',
#    'Конгрессом',
#    'США'],
#   ['В', 'Томске', 'воздушный', 'шар', 'упал', 'на', '\xa0', 'ГРЭС'],
#   ['В', 'Москве', 'обезвредили', 'очередное', 'взрывное', 'устройство'],
#   ['Россия',
#    'после',
#    'терактов',
#    ':',
#    'помощь',
#    'пострадавшим',
#    'и',
#    '\xa0',
#    'новые',
#    'меры',
#    'безопасности'],
#   ['Федеральные',
#    'войска',
#    'перекрывают',
#    'границу',
#    'между',
#    'Чечней',
#    'и',
#    '\xa0',
#    'Дагестаном'],
#   ['В', 'Испании', 'погибло', '30', '\xa0', 'туристов'],
#   ['В', 'Белоруссии', 'пропал', 'один', 'из', '\xa0', 'лидеров', 'оппозиции'],
#   ['Террорист',
#    ',',
#    'покушавшийся',
#    'на',
#    '\xa0',
#    'Клинтона',
#    ',',
#    'признал',
#    'себя',
#    'виновным'],
#   ['Усама', 'Бин', 'Ладен', 'объявил', 'Индии', 'джихад'],
#   ['В', 'Москве', 'произошел', 'новый', 'взрыв'],
#   ['Басаев',
#    'намерен',
#    'создать',
#    'подразделение',
#    '"',
#    'исламских',
#    'камикадзе',
#    '"'],
#   ['"', 'Отечество', '"', 'продолжает', 'разваливаться'],
#   ['Москва', 'заведет', 'карточку', 'на', '\xa0', 'каждого', 'иностранца'],
#   ['Жена',
#    'московского',
#    'мэра',
#    'Елена',
#    'Батурина',
#    'баллотируется',
#    'в',
#    '\xa0',
#    'Госдуму'],
#   ['Северная',
#    'Каролина',
#    ':',
#    'вслед',
#    'за',
#    '\xa0',
#    'ураганом',
#    '\xa0',
#    '—',
#    'наводнение'],
#   ['Сергей', 'Шойгу', 'получил', 'звание', 'Героя', 'России'],
#   ['Россия', 'окажет', 'Киргизии', 'военную', 'помощь'],
#   ['Усама',
#    'Бин',
#    'Ладен',
#    'обиделся',
#    'на',
#    '\xa0',
#    'старших',
#    'братьев',
#    'и',
#    '\xa0',
#    'стал',
#    'террористом'],
#   ['Владимир',
#    'Путин',
#    ':',
#    '"',
#    'Организаторы',
#    'терактов',
#    'будут',
#    'уничтожены',
#    'непременно',
#    '"'],
#   ['Албанские',
#    'сепаратисты',
#    'будут',
#    'разоружаться',
#    'еще',
#    '48',
#    '\xa0',
#    'часов'],
#   ['У',
#    'бразильского',
#    'футболиста',
#    'Ромарио',
#    'отобрали',
#    '"',
#    'Мерседес',
#    '"'],
#   ['Дмитрий',
#    'Якушкин',
#    'опроверг',
#    'слухи',
#    'о',
#    '\xa0',
#    'досрочной',
#    'отставке',
#    'Ельцина'],
#   ['Три',
#    'корейца',
#    '-',
#    'ядерщика',
#    'взорвались',
#    'в',
#    '\xa0',
#    'лаборатории'],
#   ['В',
#    'Ленинградской',
#    'области',
#    'прошел',
#    'первый',
#    'тур',
#    'выборов',
#    'губернатора'],
#   ['Степашин',
#    ':',
#    'вопрос',
#    'о',
#    '\xa0',
#    'независимости',
#    'Чечни',
#    'нужно',
#    'вынести',
#    'на',
#    '\xa0',
#    'референдум'],
#   ['Миротворцы', 'начинают', 'операцию', 'в', '\xa0', 'Восточном', 'Тиморе'],
#   ['Виктор', 'Кресс', 'сохранил', 'пост', 'губернатора', 'Томской', 'области'],
#   ['В', 'Нью', '-', 'Йорке', 'судят', 'российских', 'бандитов'],
#   ['Генсек',
#    'ООН',
#    ':',
#    'Национальный',
#    'суверенитет',
#    '\xa0',
#    '—',
#    'не',
#    '\xa0',
#    'помеха',
#    'миротворческой',
#    'интервенции'],
#   ['Эпидемия', 'отравления', 'грибами', 'в', '\xa0', 'Воронежской', 'области'],
#   ['День',
#    'рождения',
#    'Лужкова',
#    ':',
#    'поздравление',
#    'от',
#    '\xa0',
#    'Ельцина',
#    'и',
#    '"',
#    'кибер',
#    '-',
#    'подарок',
#    '"',
#    'от',
#    '\xa0',
#    'неизвестного'],
#   ['Юрий',
#    'Лужков',
#    ':',
#    'отставка',
#    'Ельцина',
#    '"',
#    'достаточно',
#    'реальна',
#    '"'],
#   ['Хакерская', 'группа', 'взломала', 'сайт', 'NASDAQ'],
#   ['Уроженец',
#    'Ирана',
#    '11',
#    '\xa0',
#    'лет',
#    'жил',
#    'во',
#    '\xa0',
#    'французском',
#    'аэропорту'],
#   ['Мужа',
#    'Беназир',
#    'Бхутто',
#    'обвиняют',
#    'в',
#    '\xa0',
#    'пособничестве',
#    'наркомафии'],
#   ['Землетрясение',
#    'на',
#    '\xa0',
#    'Тайване',
#    ':',
#    '1400',
#    '\xa0',
#    'человек',
#    'погибли',
#    ',',
#    'более',
#    '3',
#    '\xa0',
#    'тысяч',
#    '\xa0',
#    '—',
#    'ранены'],
#   ['В',
#    'списке',
#    'ЛДПР',
#    'есть',
#    'кандидаты',
#    ',',
#    'с',
#    '\xa0',
#    'которых',
#    'не',
#    '\xa0',
#    'снята',
#    'судимость'],
#   ['Депутаты',
#    'Госдумы',
#    'примут',
#    'участие',
#    'в',
#    '\xa0',
#    'слушаниях',
#    'по',
#    '\xa0',
#    'коррупции',
#    'в',
#    '\xa0',
#    'Конгрессе',
#    'США'],
#   ['Хакеры', 'угрожают', 'банкам', 'и', '\xa0', 'требуют', 'выкуп'],
#   ['Заплатит',
#    'ли',
#    '\xa0',
#    'Беларусь',
#    'за',
#    '\xa0',
#    'роcсийский',
#    'газ',
#    '?'],
#   ['"', 'Британский', 'Дом', '"', 'закрывается'],
#   ['Основатель',
#    'MTV',
#    'заплатит',
#    'за',
#    '\xa0',
#    'развод',
#    'целое',
#    'состояние'],
#   ['Дома',
#    'для',
#    'взрывов',
#    'террористы',
#    'находили',
#    'по',
#    '\xa0',
#    'газете',
#    '"',
#    'Из',
#    'рук',
#    'в',
#    '\xa0',
#    'руки',
#    '"'],
#   ['Лунную',
#    'пыль',
#    'продали',
#    'за',
#    '\xa0',
#    '310',
#    '\xa0',
#    'тысяч',
#    'долларов'],
#   ['Таможенник',
#    'набрал',
#    'взяток',
#    'на',
#    '\xa0',
#    '188',
#    '\xa0',
#    'тысяч',
#    'долларов',
#    'за',
#    '\xa0',
#    'махинации',
#    'с',
#    '\xa0',
#    'иномарками'],
#   ['Дума', 'обещает', 'возвращать', 'деньги', 'обманутым', 'вкладчикам'],
#   ['Генштаб',
#    'РФ',
#    '\xa0',
#    'не',
#    'исключает',
#    'проведение',
#    'наземной',
#    'операции',
#    'в',
#    '\xa0',
#    'Чечне'],
#   ['Великобритания', 'формирует', 'Иностранный', 'легион'],
#   ['Примакова', 'тоже', 'обвиняют', 'в', '\xa0', 'коррупции', '?'],
#   ['Пострадавшим',
#    'от',
#    '\xa0',
#    'взрывов',
#    'в',
#    '\xa0',
#    'Москве',
#    'выплачены',
#    'все',
#    'компенсации'],
#   ['Подписано', 'соглашение', 'об', '\xa0', 'официальном', 'статусе', 'ОАК'],
#   ['Пять', 'человек', 'погибли', 'при', 'пожаре', 'в', '\xa0', 'Петербурге'],
#   ['Указ', 'Лужкова', 'о', '\xa0', 'перерегистрации', 'нарушает', 'закон'],
#   ['Times',
#    'и',
#    '\xa0',
#    'New',
#    'York',
#    'Times',
#    'ищут',
#    'кремлевские',
#    'счета'],
#   ['ЕС',
#    'одержал',
#    'первую',
#    'победу',
#    'в',
#    '"',
#    'торговой',
#    'войне',
#    '"',
#    'с',
#    '\xa0',
#    'США'],
#   ['Российское',
#    'правительство',
#    'смогло',
#    'погасить',
#    'все',
#    'долги',
#    'по',
#    '\xa0',
#    'пенсиям'],
#   ['Повышены', 'экспортные', 'пошлины', 'на', '\xa0', 'бензин'],
#   ['Госдума',
#    'против',
#    'отправки',
#    'призывников',
#    'в',
#    '\xa0',
#    'районы',
#    'боевых',
#    'действий'],
#   ['Новые', 'подземные', 'толчки', 'на', '\xa0', 'Тайване'],
#   ['Из', 'Москвы', 'выдворят', '50', '\xa0', 'тысяч', 'человек', '?'],
#   ['Обнаружен', 'очередной', 'макровирус'],
#   ['Пострадавшим',
#    'от',
#    '\xa0',
#    'взрыва',
#    'в',
#    '\xa0',
#    'Волгодонске',
#    'выделят',
#    '50',
#    '\xa0',
#    'миллионов',
#    'рублей'],
#   ['Эксперты',
#    'из',
#    '\xa0',
#    'стран',
#    '"',
#    'большой',
#    'восьмерки',
#    '"',
#    'обсуждают',
#    '"',
#    'Проблему',
#    '2000',
#    '"'],
#   ['Начался', 'последний', 'этап', 'суда', 'над', 'Microsoft'],
#   ['Российские', 'спасатели', 'вылетели', 'на', '\xa0', 'Тайвань'],
#   ['Интернет', 'придет', 'в', '\xa0', 'индийские', 'деревни'],
#   ['Утвержден',
#    'федеральный',
#    'список',
#    '"',
#    'Российского',
#    'общенародного',
#    'союза',
#    '"'],
#   ['Прощание', 'с', '\xa0', 'Раисой', 'Горбачевой'],
#   ['Европейская', 'денежная', 'единица', 'делает', 'мощный', 'рывок', 'вверх'],
#   ['Экспортные', 'пошлины', 'на', '\xa0', 'нефть', 'будут', 'расти'],
#   ['На', 'Филиппинах', 'проснулся', 'вулкан', 'Мэйон'],
#   ['"',
#    'Отечество',
#    '"',
#    'открещивается',
#    'от',
#    '\xa0',
#    'квазиофициального',
#    'сайта',
#    'Лужкова'],
#   ['Изоляция',
#    'России',
#    'не',
#    '\xa0',
#    'отвечает',
#    'национальным',
#    'интересам',
#    'США'],
#   ['В', 'Лондоне', 'зафиксирован', 'рост', 'цен', 'на', '\xa0', 'золото'],
#   ['"', 'Аэрофлот', '"', 'будет', 'работать', 'с', '"', 'ЛУКОЙЛом', '"'],
#   ['В',
#    'Гамбурге',
#    'обнаружена',
#    'неразорвавшаяся',
#    'бомба',
#    'времен',
#    'Второй',
#    'мировой',
#    'войны'],
#   ['Мосгордума',
#    'полагает',
#    ',',
#    'что',
#    'москвичи',
#    'должны',
#    'защищать',
#    'себя',
#    'сами'],
#   ['Сторонники',
#    'Дерева',
#    'вновь',
#    'провели',
#    'митинг',
#    'в',
#    '\xa0',
#    'центре',
#    'Черкесска'],
#   ['Арестованы', 'трое', 'лидеров', 'ХАМАС'],
#   ['Верховный',
#    'суд',
#    'подтвердил',
#    'право',
#    '"',
#    'Отечества',
#    '"',
#    'участвовать',
#    'в',
#    '\xa0',
#    'выборах'],
#   ['В', 'Сербии', 'оппозиция', 'требует', 'отставки', 'Милошевича'],
#   ['У', 'Маркеса', 'выявлен', 'рак', 'лимфы'],
#   ['Границы', 'и', '\xa0', 'воздушное', 'пространство', 'Чечни', 'закрыты'],
#   ['Госдума', 'дважды', 'отклонила', 'поправки', 'к', '\xa0', 'Конституции'],
#   ['Беженцам',
#    'из',
#    '\xa0',
#    'Буйнакского',
#    'района',
#    'разрешено',
#    'вернуться',
#    'домой'],
#   ['Черепков', 'дошел', 'до', '\xa0', 'Европейского', 'суда'],
#   ['Минтопэнерго',
#    'угрожает',
#    'привлечь',
#    'к',
#    '\xa0',
#    'уголовной',
#    'ответственности',
#    'бывшего',
#    'главу',
#    '"',
#    'Транснефти',
#    '"'],
#   ['В',
#    'Санкт',
#    '-',
#    'Петербурге',
#    'повышаются',
#    'цены',
#    'на',
#    '\xa0',
#    'бензин'],
#   ['Тайфун', '"', 'Харви', '"', 'обрушился', 'на', '\xa0', 'Флориду'],
#   ['Лебедь', 'не', '\xa0', 'будет', 'управлять', 'Ачинским', 'комбинатом'],
#   ['Сергей', 'Шойгу', 'возглавит', 'новый', 'избирательный', 'блок'],
#   ['Рязанский', 'сахар', 'гексогена', 'не', '\xa0', 'содержит'],
#   ['Оползень',
#    'в',
#    '\xa0',
#    'Буйнакске',
#    ':',
#    '50',
#    '\xa0',
#    'частных',
#    'домов',
#    'полностью',
#    'разрушены'],
#   ['В',
#    'Великобритании',
#    'обсуждается',
#    'возможность',
#    'организации',
#    'Министерства',
#    'Интернета'],
#   ['Руководителей',
#    'УВД',
#    'Москвы',
#    'и',
#    '\xa0',
#    'Петербурга',
#    'привлекут',
#    'к',
#    '\xa0',
#    'ответственности'],
#   ['"',
#    'Ошибка',
#    '-',
#    '2000',
#    '"',
#    'в',
#    '\xa0',
#    'США',
#    ':',
#    'Пентагон',
#    'готовится',
#    'к',
#    '\xa0',
#    'войне'],
#   ['Горит', 'Грозненский', 'нефтекомбинат'],
#   ['NASA', 'потеряло', 'связь', 'с', '\xa0', 'марсианским', 'зондом'],
#   ['Вокзалы', 'станут', 'неприступны', 'для', '"', 'зайцев', '"'],
#   ['Ограблен', 'коммерческий', 'банк', 'в', '\xa0', 'Братске'],
#   ['Северная',
#    'Корея',
#    'не',
#    '\xa0',
#    'соглашается',
#    'вернуть',
#    'Казахстану',
#    'самолеты'],
#   ['Взрыв', 'в', '\xa0', 'Санкт', '-', 'Петербурге', ':', 'жертв', 'нет'],
#   ['Министерство',
#    'налогов',
#    'ужесточает',
#    'требования',
#    'к',
#    '\xa0',
#    'страховщикам'],
#   ['Мировые', 'цены', 'на', '\xa0', 'нефть', 'растут'],
#   ['Германия',
#    'намерена',
#    'обеспечить',
#    'доступ',
#    'в',
#    '\xa0',
#    'Интернет',
#    'всем',
#    'немцам'],
#   ['"',
#    'Банк',
#    'Москвы',
#    '"',
#    'не',
#    '\xa0',
#    'покупал',
#    'жеребца',
#    'для',
#    'Лужкова'],
#   ['Российские', 'самолеты', 'бомбят', 'Чечню'],
#   ['Раиса',
#    'Максимовна',
#    'Горбачева',
#    'похоронена',
#    'на',
#    '\xa0',
#    'Новодевичьем',
#    'кладбище'],
#   ['Федеральная',
#    'торговая',
#    'комиссия',
#    'выиграла',
#    'дело',
#    'против',
#    'порносайтов'],
#   ['В',
#    'Великобритании',
#    'перехвачена',
#    'крупнейшая',
#    'партия',
#    'поддельной',
#    '"',
#    'Виагры',
#    '"'],
#   ['Прощание', 'с', '\xa0', 'Раисой', 'Горбачевой', ':', 'фоторепортаж'],
#   ['Министерство',
#    'юстиции',
#    'США',
#    'не',
#    '\xa0',
#    'дало',
#    'Конгрессу',
#    'документов',
#    'по',
#    '\xa0',
#    'cчетам',
#    'в',
#    '\xa0',
#    'Bank',
#    'of',
#    '\xa0',
#    'New',
#    'York'],
#   ['Землетрясение', 'на', '\xa0', 'Тайване', ':', '2106', '\xa0', 'погибших'],
#   ['Американские', 'спутники', 'взлетают', 'с', '\xa0', 'Байконура'],
#   ['США',
#    'выделяет',
#    '225',
#    '\xa0',
#    'миллионов',
#    'долларов',
#    'на',
#    '\xa0',
#    'борьбу',
#    'с',
#    '\xa0',
#    'биотерроризмом'],
#   ['Сумасшедший', 'покушался', 'на', '\xa0', 'картины', 'Дали'],
#   ['В',
#    'борьбу',
#    'за',
#    '"',
#    'альтернативный',
#    'сайт',
#    'Лужкова',
#    '"',
#    'вступит',
#    'ФЭП',
#    '?'],
#   ['США', 'начинает', 'суд', 'над', 'табачными', 'компаниями'],
#   ['Два', 'взрыва', 'в', '\xa0', 'Косово'],
#   ['Sony', 'выпускает', 'аудиоплейер', 'поколения', 'Интернета'],
#   ['Российский',
#    'самолет',
#    'чуть',
#    'не',
#    '\xa0',
#    'сел',
#    'на',
#    '\xa0',
#    'шоссе',
#    'Тель',
#    '-',
#    'Авив',
#    '\xa0',
#    '—',
#    'Иерусалим'],
#   ['Митингующие',
#    'в',
#    '\xa0',
#    'Черкесске',
#    'блокируют',
#    'дом',
#    'правительства'],
#   ['Hilton', 'откроет', 'отель', 'в', '\xa0', 'космосе'],
#   ['Госдума', 'намерена', 'отклонить', 'проект', 'бюджета', '-', '2000'],
#   ['Ачинский', 'комбинат', 'находится', 'на', '\xa0', 'грани', 'остановки'],
#   ['По',
#    'средам',
#    'каждый',
#    'депутат',
#    'Думы',
#    'будет',
#    'голосовать',
#    'сам',
#    'за',
#    '\xa0',
#    'себя'],
#   ['Российские', 'сайты', 'не', '\xa0', 'видны', 'из', '-', 'за', 'рубежа'],
#   ['Акции',
#    'компаний',
#    'high',
#    '-',
#    'tech',
#    'резко',
#    'упали',
#    'в',
#    '\xa0',
#    'цене'],
#   ['Владимир',
#    'Путин',
#    ':',
#    'авиаудары',
#    'по',
#    '\xa0',
#    'Чечне',
#    'будут',
#    'продолжаться'],
#   ['Марсианский', 'зонд', 'погубила', 'запятая', '?'],
#   ['МВФ',
#    'оказывает',
#    'содействие',
#    'в',
#    '\xa0',
#    'решении',
#    'проблемы',
#    '2000',
#    '\xa0',
#    'года'],
#   ['Агентству', '"', 'Интерфакс', '"', 'исполнилось', '10', '\xa0', 'лет'],
#   ['На', 'пост', 'мэра', 'Москвы', 'претендуют', 'семеро'],
#   ['В',
#    'Новгороде',
#    'расследуется',
#    'дело',
#    'о',
#    '\xa0',
#    'детской',
#    'порнографии',
#    'в',
#    '\xa0',
#    'Интернете'],
#   ['Госдума', 'хочет', 'запретить', 'летнее', 'время'],
#   ['Среди',
#    'тех',
#    ',',
#    'кто',
#    'взрывал',
#    'дома',
#    ',',
#    'не',
#    '\xa0',
#    'было',
#    'ни',
#    '\xa0',
#    'одного',
#    'чеченца'],
#   ['Погода', ':', 'прогноз', '-', '2000'],
#   ['Основатели',
#    'Microsoft',
#    'Гейтс',
#    'и',
#    '\xa0',
#    'Аллен',
#    'богаче',
#    'всех',
#    'в',
#    '\xa0',
#    'мире'],
#   ['Черномырдин',
#    'и',
#    '\xa0',
#    'НДР',
#    'для',
#    'пользы',
#    'дела',
#    'готовы',
#    'сотрудничать',
#    'с',
#    '"',
#    'Единством',
#    '"'],
#   ['Москва', 'не', '\xa0', 'платит', 'налоги'],
#   ['В',
#    'Зеленограде',
#    'закрыт',
#    'завод',
#    'по',
#    '\xa0',
#    'производству',
#    'пиратских',
#    'компакт',
#    '-',
#    'дисков'],
#   ['Степашин',
#    ':',
#    '"',
#    'Ужесточение',
#    'режима',
#    'регистрации',
#    'в',
#    '\xa0',
#    'Москве',
#    'граничит',
#    'с',
#    '\xa0',
#    'этническими',
#    'чистками',
#    '"'],
#   ['"', 'Аэрофлот', '"', 'подготовился', 'к', '\xa0', 'возможным', 'терактам'],
#   ['Взрыв',
#    'в',
#    '\xa0',
#    'Рязани',
#    ':',
#    'ФСБ',
#    'ставит',
#    'опыты',
#    'на',
#    '\xa0',
#    'людях'],
#   ['Биржи',
#    'Европы',
#    'переходят',
#    'на',
#    '\xa0',
#    'единую',
#    'систему',
#    'электронной',
#    'связи'],
#   ['Россия',
#    'вышла',
#    'на',
#    '\xa0',
#    'первое',
#    'место',
#    'в',
#    '\xa0',
#    'мире',
#    'по',
#    '\xa0',
#    'внешнему',
#    'долгу'],
# ...
#    'O',
#    'O',
#    'O',
#    'B-DATE',
#    'I-DATE',
#    'O'],
#   ['B-CARDINAL', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-NORP', 'O'],
#   ['B-EVENT', 'I-EVENT', 'O', 'O', 'O', 'O', 'O', 'B-GPE'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-CARDINAL', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'B-PERSON', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'B-NORP', 'O', 'O', 'O', 'B-NORP', 'O'],
#   ['O', 'B-LOC', 'I-LOC', 'O', 'B-CARDINAL', 'O'],
#   ['B-PERSON', 'I-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'B-ORDINAL', 'O', 'B-ORDINAL', 'O', 'B-ORG', 'I-ORG', 'I-ORG'],
#   ['O', 'B-GPE', 'O', 'O', 'O', 'O', 'B-CARDINAL', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-GPE',
#    'I-GPE',
#    'I-GPE',
#    'O',
#    'B-CARDINAL',
#    'I-CARDINAL',
#    'O',
#    'O'],
#   ['B-ORDINAL', 'O', 'O', 'O', 'B-GPE', 'O', 'O', 'O', 'O'],
#   ['B-PERSON',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ORG'],
#   ['O', 'O', 'O', 'O', 'O', 'B-TIME', 'I-TIME', 'I-TIME', 'O', 'O', 'O', 'O'],
#   ['O', 'B-ORG', 'O', 'O', 'B-NORP', 'O'],
#   ['B-ORG', 'I-ORG', 'B-ORG', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'I-LOC'],
#   ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'B-PERSON', 'O', 'O', 'O', 'O', 'O'],
#   ['B-PERSON', 'O', 'O', 'B-PERSON', 'O', 'O', 'O', 'B-LOC'],
#   ['O', 'B-GPE', 'O', 'B-GPE', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'B-LOC', 'I-LOC', 'O', 'O'],
#   ['O', 'B-GPE', 'O', 'O', 'O', 'B-WORK_OF_ART', 'I-WORK_OF_ART'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['B-ORG', 'O', 'O', 'O', 'O', 'B-ORG', 'O'],
#   ['O', 'B-GPE', 'O', 'O', 'O', 'O', 'B-CARDINAL', 'O', 'O'],
#   ['O', 'O', 'O', 'B-LOC'],
#   ['B-GPE',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-CARDINAL',
#    'I-CARDINAL',
#    'I-CARDINAL',
#    'I-CARDINAL',
#    'O',
#    'O',
#    'O'],
#   ['B-ORG',
#    'I-ORG',
#    'I-ORG',
#    'O',
#    'B-PERSON',
#    'I-PERSON',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PERSON'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-GPE'],
#   ['O',
#    'B-GPE',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-CARDINAL',
#    'I-CARDINAL',
#    'I-CARDINAL',
#    'O'],
#   ['O', 'B-GPE', 'I-GPE', 'O', 'B-CARDINAL', 'O', 'O', 'O'],
#   ['O', 'B-GPE', 'O', 'O', 'O', 'O', 'O', 'O', 'B-GPE'],
#   ['O', 'B-GPE', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-GPE'],
#   ['B-GPE', 'O', 'O'],
#   ['O',
#    'B-GPE',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ORG',
#    'I-ORG',
#    'I-ORG',
#    'I-ORG',
#    'I-ORG'],
#   ['B-GPE', 'I-GPE', 'O', 'O', 'O', 'B-GPE'],
#   ['O', 'B-NORP', 'O', 'O', 'O', 'O', 'O', 'B-NORP', 'O', 'O', 'O', 'O'],
#   ['B-PERSON', 'O', 'B-GPE', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-GPE'],
#   ['B-PERSON', 'O', 'O', 'O', 'O'],
#   ['O', 'B-PERSON', 'I-PERSON', 'O'],
#   ['O', 'B-GPE', 'O', 'O', 'O', 'O', 'O'],
#   ['B-GPE', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-GPE'],
#   ['B-PERSON', 'O', 'B-GPE', 'O', 'O', 'O', 'O'],
#   ['B-PERSON', 'I-PERSON', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'B-NORP',
#    'O',
#    'B-GPE',
#    'O',
#    'O',
#    'B-GPE',
#    'O',
#    'B-CARDINAL',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-GPE', 'O', 'O'],
#   ['O', 'O', 'B-CARDINAL', 'O', 'O', 'O', 'O', 'O', 'B-GPE'],
#   ['O', 'B-DATE', 'I-DATE', 'B-GPE', 'O', 'O', 'O'],
#   ['B-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['B-PERSON',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-NORP',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O', 'B-GPE', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['B-ORG', 'O', 'O', 'B-WORK_OF_ART', 'I-WORK_OF_ART', 'O'],
#   ['O', 'B-PERSON', 'I-PERSON', 'O', 'O', 'O', 'O', 'B-NORP', 'O', 'O'],
#   ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'B-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O'],
#   ['B-GPE', 'O', 'O', 'B-GPE', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'B-GPE', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-GPE'],
#   ['B-EVENT', 'I-EVENT', 'O', 'O', 'B-CARDINAL', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'O', 'O', 'O', 'O'],
#   ['B-CARDINAL',
#    'I-CARDINAL',
#    'I-CARDINAL',
#    'I-CARDINAL',
#    'B-NORP',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-NORP',
#    'O'],
#   ['B-PERSON', 'I-PERSON', 'O', 'B-ORG', 'O', 'O', 'O', 'O'],
#   ['O', 'B-GPE', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'B-MONEY',
#    'I-MONEY',
#    'I-MONEY',
#    'I-MONEY',
#    'O',
#    'O',
#    'B-ORG'],
#   ['B-CARDINAL', 'O', 'O', 'O', 'B-GPE', 'O', 'O'],
#   ['O', 'O', 'O', 'O'],
#   ['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'B-GPE'],
#   ['B-PERSON', 'O', 'O', 'O', 'O', 'O', 'B-PERSON'],
#   ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'B-GPE', 'O', 'O', 'B-PERSON'],
#   ['O', 'O', 'O', 'O', 'O', 'B-GPE'],
#   ['B-PERSON', 'O', 'O', 'O', 'O', 'B-LOC'],
#   ['B-ORG', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'B-PERSON', 'I-PERSON'],
#   ['B-CARDINAL',
#    'I-CARDINAL',
#    'I-CARDINAL',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'I-LOC'],
#   ['B-NORP', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG'],
#   ['O', 'B-GPE', 'O', 'O', 'O', 'O', 'O', 'B-FAC'],
#   ['O', 'B-GPE', 'O', 'O', 'O', 'O'],
#   ['B-GPE', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'B-GPE', 'O', 'O', 'B-GPE'],
#   ['O', 'B-GPE', 'O', 'B-CARDINAL', 'O', 'O'],
#   ['O', 'B-GPE', 'O', 'B-CARDINAL', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'B-PERSON', 'O', 'O', 'O', 'O'],
#   ['B-PERSON', 'I-PERSON', 'I-PERSON', 'O', 'B-GPE', 'O'],
#   ['O', 'B-GPE', 'O', 'O', 'O'],
#   ['B-PERSON', 'O', 'O', 'O', 'O', 'B-NORP', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O'],
#   ['B-GPE', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'B-GPE', 'O', 'B-PERSON', 'I-PERSON', 'O', 'O', 'O', 'B-ORG'],
#   ['B-GPE', 'I-GPE', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['B-PERSON', 'I-PERSON', 'O', 'O', 'O', 'B-GPE'],
#   ['B-GPE', 'O', 'B-GPE', 'O', 'O'],
#   ['B-PERSON',
#    'I-PERSON',
#    'I-PERSON',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['B-PERSON', 'I-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['B-NORP', 'O', 'O', 'O', 'B-TIME', 'I-TIME', 'I-TIME', 'I-TIME'],
#   ['O', 'B-NORP', 'O', 'B-PERSON', 'O', 'O', 'O', 'O'],
#   ['B-PERSON', 'I-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON'],
#   ['B-CARDINAL', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'B-GPE', 'I-GPE', 'O', 'B-ORDINAL', 'O', 'O', 'O'],
#   ['B-PERSON', 'O', 'O', 'O', 'O', 'O', 'B-GPE', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'B-LOC', 'I-LOC'],
#   ['B-PERSON', 'I-PERSON', 'O', 'O', 'O', 'B-GPE', 'I-GPE'],
#   ['O', 'B-GPE', 'I-GPE', 'I-GPE', 'O', 'B-NORP', 'O'],
#   ['B-PERSON', 'B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'B-GPE', 'I-GPE'],
#   ['O',
#    'O',
#    'B-PERSON',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PERSON',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['B-PERSON', 'I-PERSON', 'O', 'O', 'B-PERSON', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'B-ORG'],
#   ['O', 'B-GPE', 'B-DATE', 'I-DATE', 'I-DATE', 'O', 'O', 'O', 'B-NORP', 'O'],
#   ['O', 'B-PERSON', 'I-PERSON', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'B-GPE',
#    'O',
#    'B-CARDINAL',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-CARDINAL',
#    'I-CARDINAL',
#    'I-CARDINAL',
#    'I-CARDINAL',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'B-ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ORG',
#    'I-ORG'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'B-GPE', 'O', 'O', 'O', 'O', 'O'],
#   ['B-FAC', 'I-FAC', 'I-FAC', 'I-FAC', 'O'],
#   ['O', 'B-ORG', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-WORK_OF_ART',
#    'I-WORK_OF_ART',
#    'I-WORK_OF_ART',
#    'I-WORK_OF_ART',
#    'I-WORK_OF_ART',
#    'I-WORK_OF_ART',
#    'I-WORK_OF_ART'],
#   ['O', 'O', 'O', 'O', 'O', 'B-MONEY', 'I-MONEY', 'I-MONEY', 'I-MONEY'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-MONEY',
#    'I-MONEY',
#    'I-MONEY',
#    'I-MONEY',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['B-ORG', 'O', 'O', 'O', 'O', 'O'],
#   ['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-GPE'],
#   ['B-GPE', 'O', 'B-ORG', 'I-ORG'],
#   ['B-PERSON', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'B-GPE', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'B-ORG'],
#   ['B-CARDINAL', 'O', 'O', 'O', 'O', 'O', 'O', 'B-GPE'],
#   ['O', 'B-PERSON', 'O', 'O', 'O', 'O', 'O'],
#   ['B-ORG', 'O', 'O', 'B-ORG', 'I-ORG', 'I-ORG', 'O', 'O', 'O'],
#   ['B-ORG', 'O', 'B-ORDINAL', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-GPE'],
#   ['B-GPE', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O'],
#   ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'B-GPE'],
#   ['O', 'B-GPE', 'O', 'B-CARDINAL', 'I-CARDINAL', 'I-CARDINAL', 'O', 'O'],
#   ['O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-GPE',
#    'O',
#    'B-MONEY',
#    'I-MONEY',
#    'I-MONEY',
#    'I-MONEY'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-DATE', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'B-ORG'],
#   ['B-NORP', 'O', 'O', 'O', 'O', 'B-GPE'],
#   ['O', 'O', 'O', 'O', 'B-NORP', 'O'],
#   ['O', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'I-ORG', 'O'],
#   ['O', 'O', 'O', 'B-PERSON', 'I-PERSON'],
#   ['B-NORP', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'B-GPE', 'O', 'O', 'B-LOC'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON'],
#   ['O', 'B-GPE', 'O', 'O', 'O', 'O', 'O', 'B-GPE'],
#   ['O', 'B-GPE', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'B-ORG', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'O'],
#   ['O', 'B-GPE', 'O', 'O', 'O', 'O', 'B-EVENT', 'I-EVENT', 'I-EVENT'],
#   ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'B-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'B-GPE'],
#   ['O', 'O', 'O', 'B-ORG'],
#   ['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'B-GPE', 'O', 'O', 'O', 'B-PERSON'],
#   ['O', 'B-PERSON', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'B-GPE', 'O'],
#   ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'B-LAW'],
#   ['O', 'O', 'O', 'B-GPE', 'O', 'O', 'O', 'O'],
#   ['B-PERSON', 'O', 'O', 'O', 'O', 'O'],
#   ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORG', 'O'],
#   ['O', 'B-GPE', 'I-GPE', 'I-GPE', 'O', 'O', 'O', 'O', 'O'],
#   ['B-PERSON', 'I-PERSON', 'I-PERSON', 'I-PERSON', 'O', 'O', 'O', 'B-GPE'],
#   ['B-PERSON', 'O', 'O', 'O', 'O', 'B-ORG', 'I-ORG'],
#   ['B-PERSON', 'I-PERSON', 'O', 'O', 'O', 'O'],
#   ['B-GPE', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'B-GPE', 'O', 'B-CARDINAL', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'B-GPE', 'O', 'O', 'O', 'B-ORG', 'I-ORG'],
#   ['O', 'B-ORG', 'I-ORG', 'O', 'O', 'B-GPE', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'B-DATE',
#    'O',
#    'O',
#    'O',
#    'B-GPE',
#    'O',
#    'B-ORG',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['B-ORG', 'I-ORG', 'I-ORG'],
#   ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'B-GPE'],
#   ['B-GPE', 'I-GPE', 'O', 'O', 'O', 'O', 'B-GPE', 'O'],
#   ['O', 'O', 'O', 'B-GPE', 'I-GPE', 'I-GPE', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O'],
#   ['B-GPE', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-NORP'],
#   ['B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'B-PERSON'],
#   ['B-NORP', 'O', 'O', 'B-GPE'],
#   ['B-PERSON', 'I-PERSON', 'I-PERSON', 'O', 'O', 'O', 'B-FAC', 'I-FAC'],
#   ['B-ORG', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'O'],
#   ['O', 'B-GPE', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'B-PERSON', 'I-PERSON', 'O', 'O'],
#   ['O',
#    'O',
#    'B-GPE',
#    'O',
#    'O',
#    'O',
#    'B-ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ORG',
#    'I-ORG',
#    'I-ORG',
#    'I-ORG',
#    'I-ORG'],
#   ['O', 'O', 'O', 'B-GPE', 'O', 'B-CARDINAL', 'O', 'O'],
#   ['B-NORP', 'O', 'O', 'O', 'O', 'B-GPE'],
#   ['B-GPE',
#    'O',
#    'B-MONEY',
#    'I-MONEY',
#    'I-MONEY',
#    'I-MONEY',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O', 'B-PERSON'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'O', 'O', 'B-ORG', 'O'],
#   ['B-GPE', 'O', 'O', 'O', 'O', 'O'],
#   ['B-CARDINAL', 'O', 'O', 'O', 'B-GPE'],
#   ['B-ORG', 'O', 'O', 'O', 'B-PRODUCT'],
#   ['B-NORP',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-GPE',
#    'I-GPE',
#    'I-GPE',
#    'O',
#    'O',
#    'B-FAC'],
#   ['O', 'O', 'O', 'B-GPE', 'O', 'O', 'O'],
#   ['B-ORG', 'O', 'O', 'O', 'O', 'O'],
#   ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'B-DATE'],
#   ['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'B-ORG', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['B-PERSON', 'I-PERSON', 'O', 'O', 'O', 'O', 'B-GPE', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O'],
#   ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'B-DATE', 'I-DATE', 'I-DATE'],
#   ['O', 'O', 'B-ORG', 'I-ORG', 'O', 'B-DATE', 'I-DATE', 'I-DATE'],
#   ['O', 'O', 'O', 'B-GPE', 'O', 'B-CARDINAL'],
#   ['O', 'B-GPE', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['B-ORG', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-CARDINAL',
#    'B-NORP'],
#   ['O', 'O', 'O', 'O', 'B-DATE'],
#   ['O', 'B-ORG', 'I-ORG', 'O', 'O', 'B-PERSON', 'O', 'O', 'O', 'O', 'O'],
#   ['B-PERSON', 'O', 'O', 'B-GPE', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['B-GPE', 'O', 'O', 'O', 'O'],
#   ['O', 'B-GPE', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['B-PERSON',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-GPE',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'B-GPE', 'O', 'B-ORG', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['B-GPE',
#    'O',
#    'O',
#    'O',
#    'B-ORDINAL',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'B-GPE', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['B-NORP', 'O', 'O', 'B-NORP', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'B-GPE', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'B-GPE', 'O', 'O', 'O', 'O'],
#   ['B-GPE', 'O', 'O', 'O', 'O', 'O', 'B-GPE', 'O'],
#   ['O', 'B-ORG', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'B-CARDINAL', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'B-GPE'],
#   ['O', 'B-GPE', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-GPE'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PRODUCT'],
#   ['B-ORG', 'I-ORG', 'I-ORG', 'O', 'O', 'B-GPE', 'O', 'O', 'O', 'O'],
#   ['B-NORP', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'B-PERSON', 'I-PERSON'],
#   ['B-PERSON',
#    'O',
#    'O',
#    'B-PERSON',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PERSON',
#    'I-PERSON'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'B-GPE',
#    'O',
#    'B-CARDINAL',
#    'I-CARDINAL',
#    'I-CARDINAL',
#    'O'],
#   ['B-PERSON',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-MONEY',
#    'I-MONEY',
#    'I-MONEY',
#    'I-MONEY',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'B-GPE',
#    'O',
#    'B-CARDINAL',
#    'O',
#    'B-CARDINAL',
#    'O',
#    'O',
#    'O',
#    'B-LOC'],
#   ['O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'B-LOC', 'I-LOC', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'B-ORG', 'O', 'O', 'O', 'O'],
#   ['B-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON'],
#   ['B-GPE', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['B-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['B-NORP', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['B-ORG', 'O', 'O', 'O', 'O', 'B-LOC'],
#   ['B-ORG', 'O', 'O', 'O', 'O', 'O'],
#   ['B-PERSON', 'O', 'O', 'O', 'O', 'B-PERSON'],
#   ['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'B-GPE', 'I-GPE', 'I-GPE']]]

# %%
titles_with_entities = []

for title_tokens, entities in zip(*ner_titles):
    title_entities = []
    current_word = []
    last_entity_desc = None
    
    for token, entity_desc in zip(title_tokens, entities):
        if len(current_word) > 0 and entity_desc == 'O':
            title_entities.append((' '.join(current_word), last_entity_desc))
            current_word = []
        
        if entity_desc != 'O':
            if entity_desc[0] == 'B':
                last_entity_desc = entity_desc

            current_word.append(token)
    
    titles_with_entities.append(title_entities)

# %%
titles_with_entities
# Out:
# [[('1914', 'B-DATE'), ('Русские', 'B-NORP')],
#  [('1914', 'B-DATE'), ('М . Ю . Лермонтова', 'B-PERSON')],
#  [('1914', 'B-DATE'), ('Nesteroff', 'B-PERSON')],
#  [('1914', 'B-DATE')],
#  [('1914', 'B-DATE'), ('Люблином', 'B-GPE')],
#  [],
#  [('Москвы', 'B-GPE'), ('30', 'B-CARDINAL')],
#  [('Япония', 'B-GPE'), ('Россию', 'B-GPE')],
#  [('Британцы', 'B-NORP')],
#  [('Bank of \xa0 NY', 'B-ORG')],
#  [('1 \xa0 сентября', 'B-DATE')],
#  [('ФСБ', 'B-ORG')],
#  [('Южно - Сахалинск', 'B-GPE')],
#  [],
#  [('одно', 'B-CARDINAL'),
#   ('Турции', 'B-GPE'),
#   ('один', 'B-CARDINAL'),
#   ('около 70', 'B-CARDINAL')],
#  [('Дагестана', 'B-GPE')],
#  [('Карачаево - Черкесия', 'B-GPE')],
#  [('Коржаков', 'B-PERSON'), ('Генпрокуратуре', 'B-ORG')],
#  [('Российские', 'B-NORP')],
#  [('Киргизия', 'B-GPE'), ('Таджикистаном', 'B-GPE')],
#  [('Литва', 'B-GPE')],
#  [('Восточного Тимора', 'B-LOC')],
#  [('США', 'B-GPE'), ('Китаю 4 , 5 \xa0 миллиона долларов', 'B-MONEY')],
#  [('Илюхин', 'B-PERSON'), ('Исаков', 'B-PERSON')],
#  [('Дель Понти', 'B-PERSON')],
#  [('ФБР', 'B-ORG')],
#  [('" Bank of \xa0 New York "', 'B-ORG')],
#  [('Дагестане', 'B-GPE')],
#  [('Киргизии', 'B-GPE')],
#  [('ММВБ', 'B-ORG')],
#  [('Американские', 'B-NORP')],
#  [('ММВБ', 'B-ORG'), ('немецкими', 'B-NORP')],
#  [('Швейцарец', 'B-NORP')],
#  [('Буэнос - Айреса', 'B-GPE'), ('130', 'B-CARDINAL')],
#  [('США', 'B-GPE')],
#  [('Минюст', 'B-GPE')],
#  [('абхазский', 'B-NORP')],
#  [('Apple', 'B-ORG')],
#  [('Манежной', 'B-PRODUCT')],
#  [('Bank of \xa0 New York', 'B-ORG')],
#  [('Восточный Тимор', 'B-LOC')],
#  [('дагестанского', 'B-NORP')],
#  [('Павелецком', 'B-GPE')],
#  [],
#  [('\xa0 Свято - Троицкого собора', 'B-FAC'), ('Сан - Франциско', 'B-GPE')],
#  [('Чечне', 'B-GPE'), ('ОРТ', 'B-ORG')],
#  [('CША', 'B-ORG'), ('России', 'B-GPE')],
#  [('Танзании', 'B-GPE')],
#  [('КНДР', 'B-GPE')],
#  [('Минпечати', 'B-ORG'), ('Петербург', 'B-ORG')],
#  [('Курдская', 'B-NORP')],
#  [('Баткенском', 'B-GPE'), ('Киргизии', 'B-GPE')],
#  [],
#  [('Москве', 'B-GPE')],
#  [('ФБР', 'B-ORG'), ('более 80', 'B-CARDINAL')],
#  [('Москве', 'B-GPE')],
#  [('Манежной', 'B-PRODUCT')],
#  [],
#  [('Гонконге', 'B-GPE')],
#  [('Алтае', 'B-LOC')],
#  [('Минпечати', 'B-ORG'), ('Петербург', 'B-ORG')],
#  [('Ельцину', 'B-PERSON')],
#  [('первой', 'B-ORDINAL')],
#  [('РФ', 'B-ORG'), ('Михаил Задорнов', 'B-PERSON')],
#  [('Владимир Путин', 'B-PERSON')],
#  [('Южно - Сахалинске', 'B-GPE'), ('8', 'B-CARDINAL')],
#  [('Восточном Тиморе', 'B-LOC')],
#  [('Брюссельский', 'B-GPE')],
#  [('НАТО', 'B-ORG')],
#  [('новозеландским', 'B-NORP')],
#  [('ТРК " Петербург "', 'B-ORG')],
#  [('Москве', 'B-GPE')],
#  [('ОРТ', 'B-ORG')],
#  [('двух российских', 'B-NORP'), ('ангольских', 'B-NORP')],
#  [('Кремля', 'B-FAC'), ('Швейцарии', 'B-GPE'), ('24', 'B-CARDINAL')],
#  [('Техасе', 'B-GPE')],
#  [('Карамахи', 'B-PRODUCT')],
#  [('Севастополе', 'B-GPE')],
#  [],
#  [],
#  [],
#  [('Mabetex', 'B-ORG'), ('" Corrierre della Sera', 'B-ORG')],
#  [('Каму', 'B-LOC'), ('100 \xa0 тонн', 'B-QUANTITY')],
#  [('Станислава Дерева', 'B-PERSON')],
#  [('Омской', 'B-LOC'), ('Новгородской', 'B-GPE')],
#  [('Трое', 'B-CARDINAL'), ('Хайфе', 'B-GPE')],
#  [('бухту Ласпи', 'B-LOC')],
#  [('Чечни', 'B-GPE'), ('Россия', 'B-GPE')],
#  [('Манежной площади', 'B-FAC'), ('шесть', 'B-CARDINAL')],
#  [],
#  [('11', 'B-CARDINAL'), ('чеченского', 'B-NORP')],
#  [('Непале', 'B-GPE'), ('15', 'B-CARDINAL')],
#  [],
#  [('Пентагон', 'B-ORG'), ('российских', 'B-NORP')],
#  [('Госдумы Селезнев', 'B-PERSON')],
#  [('Чеченский', 'B-NORP'), ('Хаттаб', 'B-PERSON')],
#  [],
#  [('Дагестане', 'B-GPE')],
#  [('200', 'B-CARDINAL'), ('ООН', 'B-ORG')],
#  [('Южно - Сахалинске', 'B-LOC'), ('14', 'B-CARDINAL')],
#  [],
#  [('Китае', 'B-GPE'), ('более 200 \xa0', 'B-CARDINAL')],
#  [('Российские', 'B-NORP')],
#  [('Египта', 'B-GPE')],
#  [('Shuttle', 'B-PRODUCT')],
#  [],
#  [('швейцарских', 'B-NORP'), ('Ельцина', 'B-PERSON'), ('первый', 'B-ORDINAL')],
#  [('Инкомбанк', 'B-ORG')],
#  [('МВД', 'B-ORG'), ('российские', 'B-NORP'), ('чеченским', 'B-NORP')],
#  [('Израиля', 'B-GPE'), ('Ливаном', 'B-GPE')],
#  [('Армия освобождения Косово', 'B-ORG')],
#  [('Черкесске', 'B-GPE')],
#  [('Индонезия', 'B-GPE')],
#  [('Индии 300', 'B-CARDINAL')],
#  [('Явлинский', 'B-PERSON')],
#  [],
#  [('Казахстане', 'B-GPE')],
#  [('Протон', 'B-PRODUCT')],
#  [('Могилевич', 'B-PERSON')],
#  [('Отечество \xa0 — Вся Россия "', 'B-WORK_OF_ART'), ('ЦИК', 'B-ORG')],
#  [('Березовский', 'B-PERSON'), ('Госдуму', 'B-ORG')],
#  [('Чечне', 'B-GPE')],
#  [('Норильске четыре', 'B-CARDINAL')],
#  [('СОРМ - 2', 'B-LAW'), ('Украине', 'B-GPE')],
#  [('Генштаб РФ', 'B-ORG')],
#  [('Ачинске', 'B-GPE')],
#  [('Бородин', 'B-PERSON'), ('" Corriere della Sera', 'B-ORG')],
#  [('Ford', 'B-ORG')],
#  [('Косово', 'B-GPE')],
#  [('День четырех девяток', 'B-DATE'), ('2000', 'B-DATE')],
#  [('Москвичи', 'B-NORP'), ('Лужкова', 'B-PERSON')],
#  [('первая', 'B-ORDINAL')],
#  [('Россия', 'B-GPE')],
#  [('Клинтон', 'B-PERSON'),
#   ('Блэр', 'B-PERSON'),
#   ('Мандела', 'B-PERSON'),
#   ('Боно', 'B-PERSON'),
#   ('Дэвид Боуи', 'B-PERSON')],
#  [('австралийское', 'B-NORP')],
#  [],
#  [('Московские', 'B-GPE'), ('Нефтепродукт', 'B-ORG')],
#  [('Путин', 'B-PERSON'), ('Минск', 'B-GPE')],
#  [],
#  [('Россия', 'B-GPE'), ('Швейцарии', 'B-GPE')],
#  [('Москвы', 'B-GPE')],
#  [('Японский', 'B-NORP')],
#  [('" Мир "', 'B-FAC')],
#  [('72', 'B-CARDINAL'), ('1500', 'B-CARDINAL')],
#  [('Азербайджане', 'B-GPE')],
#  [('Москве', 'B-GPE'), ('46', 'B-CARDINAL'), ('трое', 'B-CARDINAL')],
#  [('две', 'B-CARDINAL')],
#  [('Березовский', 'B-PERSON')],
#  [('ФБР', 'B-ORG'), ('России', 'B-GPE')],
#  [('Черкесске', 'B-GPE')],
#  [('ОРТ', 'B-ORG')],
#  [('Аэрофлот', 'B-ORG')],
#  [('ЛДПР', 'B-ORG')],
#  [('Волгограде', 'B-GPE')],
#  [('Югославия', 'B-GPE'), ('Косово', 'B-GPE')],
#  [],
#  [('Дагестане', 'B-GPE'), ('российский', 'B-NORP')],
#  [('Якушкин', 'B-PERSON'), ('России', 'B-GPE')],
#  [('Чечня', 'B-GPE')],
#  [('Индонезия', 'B-GPE'), ('ООН', 'B-ORG')],
#  [('России', 'B-GPE')],
#  [('Ельцин', 'B-PERSON')],
#  [('Израиль', 'B-GPE')],
#  [('Банк Эстонии', 'B-ORG'), ('2000', 'B-DATE')],
#  [('Курске', 'B-GPE')],
#  [('Бензин', 'B-ORG'), ('Москве', 'B-GPE')],
#  [('Дагестан', 'B-GPE')],
#  [('13 \xa0 сентября', 'B-DATE'), ('России', 'B-GPE')],
#  [],
#  [('США', 'B-GPE'), ('России', 'B-GPE')],
#  [],
#  [('Генштаб', 'B-ORG')],
#  [('Франция', 'B-GPE')],
#  [('MTV', 'B-ORG'), ('1999', 'B-DATE')],
#  [('Скуратова', 'B-PERSON')],
#  [('Черкесске', 'B-GPE')],
#  [('1 \xa0 ноября', 'B-DATE'), ('Домодедово', 'B-GPE')],
#  [('Москве', 'B-GPE')],
#  [],
#  [('РФ', 'B-GPE')],
#  [],
#  [('ЦРУ', 'B-ORG'), ('США', 'B-GPE'), ('Россия', 'B-GPE'), ('Китай', 'B-GPE')],
#  [('ВГТРК', 'B-ORG')],
#  [],
#  [('Mabetex', 'B-ORG')],
#  [('Лубянке', 'B-GPE')],
#  [('Минатом', 'B-PERSON')],
#  [('ММВБ', 'B-ORG')],
#  [],
#  [('Венецианском кинофестивале', 'B-EVENT')],
#  [],
#  [('Москве', 'B-GPE')],
#  [('Россия', 'B-GPE')],
#  [('30', 'B-CARDINAL'), ('чеченских', 'B-NORP')],
#  [('Newsweek', 'B-ORG'), ('Россия', 'B-GPE')],
#  [('Москве', 'B-GPE'), ('109', 'B-CARDINAL')],
#  [('Турции', 'B-GPE')],
#  [('Россиянин', 'B-NORP'), ('США', 'B-GPE')],
#  [],
#  [('Corriere della Sera', 'B-ORG')],
#  [('Ельцин', 'B-PERSON')],
#  [('Путин', 'B-PERSON'), ('Клинтоном', 'B-PERSON')],
#  [],
#  [('Израиль', 'B-GPE'), ('палестинцы', 'B-NORP')],
#  [('Села Карамахи', 'B-PERSON'), ('Чабанмахи', 'B-GPE')],
#  [],
#  [('15 \xa0 миллиардах', 'B-CARDINAL'),
#   ('780', 'B-CARDINAL'),
#   ('российских', 'B-NORP')],
#  [('Deutsche Bank', 'B-ORG'),
#   ('Dresdner Bank', 'B-ORG'),
#   ('миллиардных', 'B-MONEY')],
#  [('Свердловской области', 'B-GPE')],
#  [('13 \xa0 сентября', 'B-DATE'), ('Москве', 'B-GPE')],
#  [('Швейцарии', 'B-GPE')],
#  [('Мытищах', 'B-GPE')],
#  [('Москве', 'B-GPE')],
#  [('Владимир Путин', 'B-PERSON')],
#  [('США', 'B-GPE')],
#  [('Ураган Флойд', 'B-EVENT'),
#   ('Флориду', 'B-GPE'),
#   ('миллион', 'B-CARDINAL')],
#  [('Виктор Калюжный', 'B-PERSON')],
#  [('16 \xa0 сентября', 'B-DATE')],
#  [('Раиса Горбачева', 'B-PERSON')],
#  [('МГУ', 'B-ORG')],
#  [('Москве', 'B-GPE'), ('121', 'B-CARDINAL')],
#  [('Москве', 'B-GPE'), ('Борисовских прудах', 'B-FAC')],
#  [('Испанская', 'B-NORP'), ('трех российских', 'B-NORP')],
#  [('160', 'B-CARDINAL'), ('российских', 'B-NORP')],
#  [('Лондоне', 'B-GPE')],
#  [('Путин', 'B-PERSON')],
#  [('Times', 'B-ORG'), ('КБ', 'B-ORG'), ('русской', 'B-NORP')],
#  [('Китай', 'B-GPE')],
#  [('Москве', 'B-GPE'), ('Дагестане', 'B-GPE')],
#  [('Греции', 'B-GPE'), ('три', 'B-CARDINAL'), ('российских', 'B-NORP')],
#  [('Казахстана', 'B-GPE'), ('Кажегельдина', 'B-PERSON')],
#  [('Карачаево - Черкесии', 'B-GPE')],
#  [],
#  [],
#  [],
#  [('Российская', 'B-NORP'), ('США', 'B-GPE')],
#  [('России', 'B-GPE'), ('США', 'B-GPE'), ('2000', 'B-DATE')],
#  [('Тысячи', 'B-CARDINAL'), ('улице Красного маяка', 'B-FAC')],
#  [('четырех дагестанских', 'B-NORP')],
#  [('Каширском шоссе', 'B-FAC')],
#  [('Чечни', 'B-GPE'), ('Москве', 'B-GPE')],
#  [('Британский', 'B-NORP'),
#   ('" Проблеме 2000 "', 'B-WORK_OF_ART'),
#   ('Украину', 'B-GPE')],
#  [('Москвы', 'B-GPE')],
#  [('Чернобыле', 'B-GPE'), ('ЧАЭС', 'B-FAC')],
#  [('ОМОН', 'B-ORG'), ('Транснефти', 'B-ORG')],
#  [('Пятеро мусульманских', 'B-NORP'),
#   ('Франции', 'B-GPE'),
#   ('десять лет', 'B-DATE')],
#  [('55', 'B-CARDINAL'), ('британского', 'B-NORP')],
#  [('Ураган Флойд', 'B-EVENT')],
#  [('27', 'B-CARDINAL')],
#  [('Ельцина', 'B-PERSON')],
#  [('российской', 'B-NORP'), ('японский', 'B-NORP')],
#  [('Северном Кавказе', 'B-LOC'), ('два', 'B-CARDINAL')],
#  [('Юрий Скуратов', 'B-PERSON')],
#  [('54', 'B-ORDINAL'), ('я', 'B-ORDINAL')],
#  [('Черкесске', 'B-GPE'), ('три', 'B-CARDINAL')],
#  [('Шри - Ланке', 'B-GPE'), ('около 200', 'B-CARDINAL')],
#  [('Первый', 'B-ORDINAL'), ('Греции', 'B-GPE')],
#  [('Лужков', 'B-PERSON')],
#  [('10 \xa0 минут', 'B-TIME')],
#  [('Barclays', 'B-ORG'), ('российских', 'B-NORP')],
#  [('Совет безопасности ООН', 'B-ORG')],
#  [('МВД', 'B-ORG')],
#  [('Лебедя', 'B-PERSON')],
#  [('Рушайло', 'B-PERSON'), ('Квашнин', 'B-PERSON')],
#  [('США', 'B-GPE'), ('России', 'B-GPE')],
#  [('Севере России', 'B-LOC')],
#  [('Анапе', 'B-GPE')],
#  [],
#  [('ОМОН', 'B-ORG'), ('Транснефть', 'B-ORG')],
#  [('Волгодонске', 'B-GPE'), ('18', 'B-CARDINAL')],
#  [],
#  [('Московская', 'B-GPE'), ('более 20 \xa0 тысяч', 'B-CARDINAL')],
#  [('New York Times', 'B-ORG'), ('Егор Строев', 'B-PERSON')],
#  [],
#  [('Чертанове', 'B-GPE'), ('4 - х', 'B-CARDINAL')],
#  [('Сахалинской области', 'B-GPE'), ('11', 'B-CARDINAL')],
#  [('Дагестане', 'B-GPE')],
#  [('Москве', 'B-GPE')],
#  [],
#  [('Черкесия', 'B-GPE')],
#  [('США', 'B-GPE')],
#  [('Тайфун Йорк', 'B-GPE')],
#  [('российской', 'B-NORP'), ('чеченцами', 'B-NORP')],
#  [('Касьянов', 'B-PERSON'), ('лондонских', 'B-GPE')],
#  [],
#  [('Милошевич', 'B-PERSON')],
#  [('Раисы Горбачевой', 'B-PERSON')],
#  [('Дагестана', 'B-GPE')],
#  [('Индонезия', 'B-GPE')],
#  [('Путин', 'B-PERSON'), ('Татарстан', 'B-GPE')],
#  [('Биньямина Нетаниягу', 'B-PERSON')],
#  [('индийском', 'B-NORP'),
#   ('Джамму', 'B-GPE'),
#   ('Кашмир', 'B-GPE'),
#   ('19', 'B-CARDINAL')],
#  [('Россию', 'B-GPE')],
#  [('8', 'B-CARDINAL')],
#  [('XXI веке Америку', 'B-GPE')],
#  [('Ельцин', 'B-PERSON')],
#  [('Березовский', 'B-PERSON'), ('российские', 'B-NORP')],
#  [('Петербурге', 'B-GPE')],
#  [('Times', 'B-ORG'), ('Архивы КГБ', 'B-WORK_OF_ART')],
#  [('Чечни Масхадов', 'B-PERSON'), ('афганского', 'B-NORP')],
#  [('МВД', 'B-ORG')],
#  [('Южной Азии', 'B-LOC')],
#  [('США', 'B-GPE'), ('России', 'B-GPE')],
#  [('Турции', 'B-GPE')],
#  [('Ураган Флойд', 'B-EVENT'), ('17', 'B-CARDINAL')],
#  [('ФБР', 'B-ORG')],
#  [('Более 20 \xa0 тысяч чеченцев', 'B-NORP'), ('российской', 'B-NORP')],
#  [('Анатолия Быкова', 'B-PERSON'), ('Интерпол', 'B-ORG')],
#  [('Москве', 'B-GPE')],
#  [('$ 15 \xa0 миллиардах', 'B-MONEY')],
#  [('Двое', 'B-CARDINAL'), ('московских', 'B-GPE')],
#  [],
#  [('Совет Федерации', 'B-ORG')],
#  [],
#  [('Ельцин', 'B-PERSON')],
#  [('Минпечати', 'B-ORG')],
#  [('Дагестане', 'B-GPE')],
#  [],
#  [('Жириновский', 'B-PERSON')],
#  [('Wall Street Journal', 'B-ORG')],
#  [],
#  [],
#  [('1 \xa0 100', 'B-CARDINAL')],
#  [('Российский', 'B-NORP')],
#  [('Томске', 'B-GPE')],
#  [('Москве', 'B-GPE')],
#  [('Россия', 'B-GPE')],
#  [('Чечней', 'B-GPE')],
#  [('Испании', 'B-GPE'), ('30', 'B-CARDINAL')],
#  [('Белоруссии', 'B-GPE'), ('один', 'B-CARDINAL')],
#  [('Клинтона', 'B-PERSON')],
#  [('Усама Бин Ладен', 'B-PERSON'), ('Индии', 'B-GPE')],
#  [('Москве', 'B-GPE')],
#  [('Басаев', 'B-PERSON'), ('исламских', 'B-NORP')],
#  [],
#  [('Москва', 'B-GPE')],
#  [('московского', 'B-GPE'), ('Елена Батурина', 'B-PERSON')],
#  [('Северная Каролина', 'B-GPE')],
#  [('Сергей Шойгу', 'B-PERSON')],
#  [('Россия', 'B-GPE'), ('Киргизии', 'B-GPE')],
#  [('Усама Бин Ладен', 'B-PERSON')],
#  [('Владимир Путин', 'B-PERSON')],
#  [('Албанские', 'B-NORP')],
#  [('бразильского', 'B-NORP'), ('Ромарио', 'B-PERSON')],
#  [('Дмитрий Якушкин', 'B-PERSON')],
#  [('Три', 'B-CARDINAL')],
#  [('Ленинградской области', 'B-GPE'), ('первый', 'B-ORDINAL')],
#  [('Степашин', 'B-PERSON'), ('Чечни', 'B-GPE')],
#  [],
#  [('Виктор Кресс', 'B-PERSON')],
#  [('Нью - Йорке', 'B-GPE'), ('российских', 'B-NORP')],
#  [('Генсек ООН', 'B-ORG')],
#  [],
#  [('Лужкова', 'B-PERSON'), ('Ельцина', 'B-PERSON')],
#  [('Юрий Лужков', 'B-PERSON'), ('Ельцина', 'B-PERSON')],
#  [],
#  [('Ирана 11 \xa0 лет', 'B-DATE'), ('французском', 'B-NORP')],
#  [('Беназир Бхутто', 'B-PERSON')],
#  [('Тайване', 'B-GPE'),
#   ('1400', 'B-CARDINAL'),
#   ('более 3 \xa0 тысяч', 'B-CARDINAL')],
#  [('ЛДПР', 'B-ORG')],
#  [('Госдумы', 'B-ORG')],
#  [],
#  [('Беларусь', 'B-GPE')],
#  [('" Британский Дом "', 'B-FAC')],
#  [('MTV', 'B-ORG')],
#  [],
#  [],
#  [('188 \xa0 тысяч долларов', 'B-MONEY')],
#  [('Дума', 'B-ORG')],
#  [('Генштаб РФ', 'B-ORG')],
#  [('Великобритания', 'B-GPE')],
#  [('Примакова', 'B-PERSON')],
#  [('Москве', 'B-GPE')],
#  [],
#  [('Пять', 'B-CARDINAL')],
#  [('Лужкова', 'B-PERSON')],
#  [('Times', 'B-ORG'), ('New York Times', 'B-ORG')],
#  [('ЕС', 'B-ORG'), ('первую', 'B-ORDINAL')],
#  [('Российское', 'B-GPE')],
#  [],
#  [('Госдума', 'B-ORG')],
#  [],
#  [('Москвы', 'B-GPE'), ('50 \xa0 тысяч', 'B-CARDINAL')],
#  [],
#  [('Волгодонске', 'B-GPE')],
#  [('2000', 'B-DATE')],
#  [],
#  [('Российские', 'B-NORP')],
#  [('индийские', 'B-NORP')],
#  [('Российского общенародного союза', 'B-ORG')],
#  [],
#  [('Европейская', 'B-NORP')],
#  [],
#  [('Филиппинах', 'B-GPE')],
#  [],
#  [('России', 'B-GPE')],
#  [('Лондоне', 'B-GPE')],
#  [('Аэрофлот', 'B-ORG'), ('ЛУКОЙЛом', 'B-ORG')],
#  [('Гамбурге', 'B-GPE')],
#  [('Мосгордума', 'B-ORG')],
#  [('Дерева', 'B-PERSON')],
#  [],
#  [('Верховный суд', 'B-ORG')],
#  [('Сербии', 'B-GPE')],
#  [('Маркеса', 'B-PERSON')],
#  [('Чечни', 'B-GPE')],
#  [('Госдума', 'B-ORG')],
#  [('Буйнакского', 'B-GPE')],
#  [('Черепков', 'B-PERSON')],
#  [('Минтопэнерго', 'B-ORG'), ('Транснефти', 'B-ORG')],
#  [('Санкт - Петербурге', 'B-GPE')],
#  [('Тайфун " Харви "', 'B-PERSON')],
#  [('Лебедь', 'B-PERSON')],
#  [('Сергей Шойгу', 'B-PERSON')],
#  [('Рязанский', 'B-GPE')],
#  [('Буйнакске', 'B-GPE'), ('50', 'B-CARDINAL')],
#  [('Великобритании', 'B-GPE')],
#  [('УВД Москвы', 'B-ORG'), ('Петербурга', 'B-GPE')],
#  [('2000', 'B-DATE'), ('США', 'B-GPE'), ('Пентагон', 'B-ORG')],
#  [],
#  [('NASA', 'B-ORG')],
#  [],
#  [],
#  [('Северная Корея', 'B-GPE'), ('Казахстану', 'B-GPE')],
#  [('Санкт - Петербурге', 'B-GPE')],
#  [],
#  [],
#  [('Германия', 'B-GPE')],
#  [('" Банк Москвы "', 'B-ORG')],
#  [('Российские', 'B-NORP')],
#  [('Раиса Максимовна Горбачева', 'B-PERSON')],
#  [('Федеральная торговая комиссия', 'B-ORG')],
#  [('Великобритании', 'B-GPE')],
#  [('Раисой Горбачевой', 'B-PERSON')],
#  [('США', 'B-GPE'), ('Конгрессу', 'B-ORG')],
#  [('Тайване', 'B-GPE'), ('2106', 'B-CARDINAL')],
#  [('Американские', 'B-NORP')],
#  [('США', 'B-GPE'), ('225 \xa0 миллионов долларов', 'B-MONEY')],
#  [],
#  [('Лужкова', 'B-PERSON'), ('ФЭП', 'B-ORG')],
#  [('США', 'B-GPE')],
#  [('Два', 'B-CARDINAL')],
#  [('Sony', 'B-ORG')],
#  [('Российский', 'B-NORP'), ('Тель - Авив', 'B-GPE')],
#  [('Черкесске', 'B-GPE')],
#  [('Hilton', 'B-ORG')],
#  [('Госдума', 'B-ORG')],
#  [('Ачинский комбинат', 'B-ORG')],
#  [('Думы', 'B-ORG')],
#  [],
#  [],
#  [('Владимир Путин', 'B-PERSON'), ('Чечне', 'B-GPE')],
#  [],
#  [('МВФ', 'B-ORG')],
#  [('Интерфакс "', 'B-ORG')],
#  [('Москвы', 'B-GPE')],
#  [('Новгороде', 'B-GPE')],
#  [('Госдума', 'B-ORG')],
#  [],
#  [],
#  [('Microsoft Гейтс', 'B-ORG'), ('Аллен', 'B-PERSON')],
#  [('Черномырдин', 'B-PERSON'), ('НДР', 'B-GPE')],
#  [('Москва', 'B-GPE')],
#  [('Зеленограде', 'B-GPE')],
#  [('Степашин', 'B-PERSON'), ('Москве', 'B-GPE')],
#  [('Аэрофлот "', 'B-ORG')],
#  [('Рязани', 'B-GPE'), ('ФСБ', 'B-ORG')],
#  [('Европы', 'B-LOC')],
#  [('Россия', 'B-GPE'), ('первое', 'B-ORDINAL')],
#  [('США', 'B-GPE')],
#  [('Шведский', 'B-NORP'), ('норвежцев', 'B-NORP')],
#  [('Бангкоке', 'B-GPE')],
#  [('Йемена', 'B-GPE')],
#  [('Тайвань', 'B-GPE'), ('Китаем', 'B-GPE')],
#  [('Совета Безопасности ООН', 'B-ORG')],
#  [('18', 'B-CARDINAL')],
#  [],
#  [('Черкесске', 'B-GPE')],
#  [],
#  [],
#  [],
#  [('Microsoft', 'B-ORG')],
#  [('G - 7', 'B-ORG'), ('России', 'B-GPE')],
#  [('Российские', 'B-NORP')],
#  [],
#  [('Лужков', 'B-PERSON'), ('Доренко', 'B-PERSON')],
#  [('Ингушетии', 'B-GPE'), ('50 \xa0 тысяч', 'B-CARDINAL')],
#  [('Клинтон', 'B-PERSON'), ('115 \xa0 миллиардов долларов', 'B-MONEY')],
#  [('Тайване', 'B-GPE'), ('6', 'B-CARDINAL'), ('8', 'B-CARDINAL')],
#  [],
#  [('Индийском океане', 'B-LOC')],
#  [('Пиночета', 'B-ORG')],
#  [('Путин', 'B-PERSON')],
#  [('Великобритания', 'B-GPE')],
#  [('IBM', 'B-ORG')],
#  [('Индонезийские', 'B-NORP')],
#  [('ОРТ', 'B-ORG')],
#  [('NASA', 'B-ORG')],
#  [('Путину', 'B-PERSON')],
#  [('Госдума России', 'B-ORG')]]

# %%
df['date']
# Out:
# 0     1914-09-16
# 1     1914-09-16
# 2     1914-09-17
# 3     1914-09-17
# 4     1914-09-18
#          ...
# 495   1999-09-27
# 496   1999-09-27
# 497   1999-09-27
# 498   1999-09-27
# 499   1999-09-27
# Name: date, Length: 500, dtype: datetime64[ns]
